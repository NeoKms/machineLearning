# %% [markdown]
# ## ЗАДАНИЕ ДЛЯ ПРОГРАММИРУЮЩИХ

# %% [markdown]
# **Ссылка**, на источник текста

# %%
DATA_URL = "http://az.lib.ru/l/leskow_n_s/text_0246.shtml"

# %% [markdown]
# Устанавливаем библиотеки

# %%
! pip install -q PyYaml==5.3.1
! pip install -q rnnmorph==0.4.0

# %% [markdown]
# Создаём объект морфологического анализатора `RNNMorph`

# %%
import warnings
warnings.filterwarnings('ignore')

from rnnmorph.predictor import RNNMorphPredictor
predictor = RNNMorphPredictor(language="ru")

# %% [markdown]
# Скачиваем текст, по которому будет дано задание, с помощью `urllib`

# %%
import urllib.request

opener = urllib.request.URLopener({})
resource = opener.open(DATA_URL)
raw_text = resource.read().decode(resource.headers.get_content_charset()) #Текс с html тегами

# %% [markdown]
# Удаляем из текста HTML-теги с помощью простого регулярного выражения (используем их, так как структура документа и небольшие ошибки с извлечением текста нас мало волнуют)

# %%
import re

clean_pattern = re.compile("<.*?>")

def clean_html(raw_html: str):
  clean_text = re.sub(clean_pattern, " ", raw_html)
  return clean_text

cleaned_text = clean_html(raw_text)#Текс без html тегов

# %% [markdown]
# С помощью библиотеки [NLTK](https://nltk.org/) разбиваем текст на предложения и токены.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
import nltk
nltk.download('punkt')

tokenized_sentences = [word_tokenize(sentence) for sentence in sent_tokenize(cleaned_text)]
"A total of %d 'sentences'" % len(tokenized_sentences)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Xiaomi\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# "A total of 468 'sentences'"

# %% [markdown]
# ## Задание 1
# С помощью метода `str.isalpha` из стандартной библиотеки Python модифицируйте нижеследующий код так, чтобы в predictions остались только буквенные токены.

# %%
from tqdm import tqdm
predictions = [[pred.normal_form for pred in sent] 
               for sent in tqdm(predictor.predict_sentences(sentences=tokenized_sentences), "sentences")]
predictions[-12:-11] #Сейчас видно, что токены типа "точка", "запятая", "дефис" и тд пока присутствуют в предложениях. От них нужно избавиться
# Out:
# sentences: 100%|█████████████████████████████████████████████████████████████████| 468/468 [00:00<00:00, 117330.20it/s]
# [['&',
#   'nbsp',
#   ';',
#   '&',
#   'nbsp',
#   ';',
#   'глава',
#   'двадцать',
#   '&',
#   'nbsp',
#   ';',
#   '&',
#   'nbsp',
#   ';',
#   'теперь',
#   'весь',
#   'это',
#   'уже',
#   '``',
#   'дело',
#   'минувший',
#   'день',
#   "''",
#   ':',
#   'и',
#   '``',
#   'предание',
#   'старина',
#   "''",
#   ',',
#   'хотя',
#   'и',
#   'не',
#   'глубокий',
#   ',',
#   'но',
#   'предание',
#   'этот',
#   'нет',
#   'нужда',
#   'торопиться',
#   'забывать',
#   ',',
#   'несмотря',
#   'на',
#   'баснословный',
#   'склад',
#   'легенда',
#   'и',
#   'эпический',
#   'характер',
#   'он',
#   'главный',
#   'герой',
#   '.']]

# %%
for i in range(len(predictions)):
    #print(str(predictions[i])+'\n')
    j=0
    lenArr=len(predictions[i])
    while (j<lenArr):
        if (not predictions[i][j].isalpha()): 
            predictions[i].pop(j)
            lenArr-=1
        else: 
            j+=1
    
for elem in predictions:
    print(str(elem)+'\n')
# Out:
# ['лесок', 'николай', 'семён']
#
# ['левша', 'лесок', 'николай', 'семён', 'левша', 'font', 'регистрация', 'найти', 'рейтинг', 'обсуждение', 'новинка', 'обзор', 'помощь', 'комментарий', 'последний', 'от']
#
# ['лесок', 'николай', 'семён', 'год', 'обновлённый']
#
# []
#
# ['статистика']
#
# ['рассказ', 'сказка', 'сказание', 'и', 'легенда', 'скачать', 'оценка', 'nbsp', 'ваш', 'оценка', 'шедевр', 'замечательный', 'очень', 'хорошо', 'хорошо', 'нормальный', 'не', 'читать', 'терпимо', 'посредственно', 'плохо', 'очень', 'плохо', 'не', 'читать', 'аннотация', 'сказ', 'о', 'тульский', 'косой', 'левша', 'и', 'о', 'стальной', 'блоха']
#
# ['верхний', 'горизонтальный', 'блок', 'для', 'azlib', 'script', 'http', 'i', 'николай', 'лесок', 'левша', 'сказ', 'о', 'тульский', 'косой', 'левша', 'и', 'о', 'стальной', 'блоха', 'nbsp', 'nbsp', 'nbsp', 'nbsp', 'изд', 'метр', 'правда', 'собрание', 'сочинение', 'в', 'пять', 'том']
#
# ['тот', 'iii']
#
# ['nbsp', 'nbsp', 'глава', 'один', 'nbsp', 'nbsp', 'когда', 'император', 'александр', 'павло', 'окончить', 'венский', 'совет', 'то', 'он', 'захотеть', 'по', 'европа', 'проездиться', 'и', 'в', 'разный', 'государство', 'чудо', 'посмотреть']
#
# ['объездить', 'он', 'весь', 'страна', 'и', 'везде', 'через', 'свой', 'ласковость', 'всегда', 'иметь', 'самый', 'междоусобный', 'разговор', 'со', 'всякий', 'человек', 'и', 'весь', 'он', 'удивлять', 'и', 'на', 'свой', 'сторона', 'преклонять', 'хотеть', 'но', 'при', 'он', 'быть', 'донской', 'казак', 'плат', 'который', 'этот', 'склонение', 'не', 'любить', 'и', 'скучать', 'по', 'свой', 'хозяйство', 'весь', 'государь', 'домой', 'манить']
#
# ['и', 'чуть', 'если', 'плат', 'заметить', 'что', 'государь', 'иностранный', 'очень', 'интересоваться', 'то', 'весь', 'провожатый', 'молчать', 'а', 'плат', 'сейчас', 'сказать', 'так', 'и', 'так', 'и', 'у', 'мы', 'дом', 'свой', 'не', 'худой', 'быть', 'и', 'отвести']
#
# ['nbsp', 'nbsp', 'англичанин', 'это', 'знать', 'и', 'к', 'приезд', 'государев', 'выдумать', 'разный', 'хитрость', 'чтобы', 'он', 'чужестранность', 'пленить', 'и', 'от', 'русский', 'отвлечь', 'и', 'в', 'многий', 'случай', 'он', 'это', 'достигать', 'особенно', 'в', 'больший', 'собрание', 'где', 'плат', 'не', 'мочь', 'вполне', 'говорить', 'но', 'он', 'это', 'мало', 'и', 'интересоваться', 'потому', 'что', 'быть', 'человек', 'женатый', 'и', 'весь', 'французский', 'разговор', 'считать', 'за', 'пустяк', 'который', 'не', 'стоять', 'воображение']
#
# ['а', 'когда', 'англичанин', 'стать', 'звать', 'государь', 'в', 'всякий', 'свой', 'цейгауза', 'оружейный', 'и', 'завод', 'чтобы', 'показать', 'свой', 'над', 'мы', 'в', 'весь', 'вещь', 'преимущество', 'и', 'тем', 'славиться', 'плат', 'сказать', 'себя', 'nbsp', 'nbsp', 'ну', 'уж', 'тут', 'шабаш']
#
# ['до', 'этот', 'пора', 'ещё', 'я', 'терпеть', 'а', 'далёкий', 'нельзя']
#
# ['суметь', 'я', 'или', 'не', 'суметь', 'говорить', 'а', 'свой', 'человек', 'не', 'выдать']
#
# ['nbsp', 'nbsp', 'и', 'только', 'он', 'сказать', 'себя', 'такой', 'слово', 'как', 'государь', 'он', 'говорить', 'nbsp', 'nbsp', 'так', 'и', 'так', 'завтра', 'мы', 'с', 'ты', 'ехать', 'он', 'оружейный', 'кунсткамера', 'смотреть']
#
# ['там', 'говорить', 'такой', 'природа', 'совершенство', 'что', 'как', 'посмотреть', 'то', 'уже', 'большой', 'не', 'быть', 'спорить', 'что', 'мы', 'русский', 'со', 'свой', 'значение', 'никуда', 'не', 'годиться']
#
# ['nbsp', 'nbsp', 'плат', 'ничто', 'государь', 'не', 'ответить', 'только', 'свой', 'грабоватый', 'нос', 'в', 'лохматый', 'бурка', 'спустить', 'а', 'прийти', 'в', 'свой', 'квартира', 'велеть', 'денщик', 'подать', 'из', 'погребец', 'фляжка', 'кавказский', 'водка', 'кизлярка', 'прима']
#
# ['автор', 'дерябнуть', 'хороший', 'стакан', 'на', 'дорожний', 'складень', 'бог', 'помолиться', 'бурка', 'укрыться', 'и', 'захрапеть', 'так', 'что', 'в', 'весь', 'дом', 'англичанин', 'никто', 'спать', 'нельзя', 'быть']
#
# ['nbsp', 'nbsp', 'думать', 'утро', 'ночь', 'мудрёный']
#
# ['nbsp', 'nbsp', 'глава', 'два', 'nbsp', 'nbsp', 'на', 'другой', 'день', 'поехать', 'государь', 'с', 'платов', 'в', 'кунсткамера']
#
# ['большой', 'государь', 'никто', 'из', 'русский', 'с', 'себя', 'не', 'взять', 'потому', 'что', 'карета', 'он', 'подать', 'двухсестный']
#
# ['nbsp', 'nbsp', 'приезжать', 'в', 'пребольшой', 'здание', 'подъезд', 'неописанный', 'коридор', 'до', 'бесконечность', 'а', 'комната', 'один', 'в', 'один', 'и', 'наконец', 'в', 'самый', 'главный', 'зал', 'разный', 'огромадный', 'бюстра', 'и', 'посредине', 'под', 'балдахин', 'стоять', 'аболон', 'полведерский']
#
# ['nbsp', 'nbsp', 'государь', 'оглядываться', 'на', 'платов', 'очень', 'ли', 'он', 'удивлённый', 'и', 'на', 'что', 'смотреть', 'а', 'то', 'идти', 'глаз', 'опустить', 'как', 'будто', 'ничто', 'не', 'видеть', 'только', 'из', 'ус', 'кольцо', 'вить']
#
# ['nbsp', 'nbsp', 'англичанин', 'сразу', 'стать', 'показывать', 'разный', 'удивление', 'и', 'пояснять', 'что', 'к', 'что', 'у', 'он', 'приноровлённый', 'для', 'военный', 'обстоятельство', 'буреметр', 'морской', 'мерблюзий', 'мантон', 'пеший', 'полок', 'а', 'для', 'конница', 'смолевой', 'непромокабль']
#
# ['государь', 'на', 'весь', 'это', 'радоваться', 'весь', 'казаться', 'он', 'очень', 'хороший', 'а', 'плат', 'держать', 'свой', 'ажидация', 'что', 'для', 'он', 'весь', 'ничто', 'не', 'значить']
#
# ['nbsp', 'nbsp', 'государь', 'говорить', 'nbsp', 'nbsp', 'как', 'это', 'возможный', 'отчего', 'в', 'ты', 'такой', 'бесчувствие']
#
# ['неужто', 'ты', 'здесь', 'ничто', 'не', 'удивительный']
#
# ['а', 'плат', 'отвечать', 'nbsp', 'nbsp', 'я', 'здесь', 'тот', 'один', 'удивительный', 'что', 'мой', 'без', 'весь', 'это', 'воевать', 'и', 'дванадесять', 'язык', 'прогнать']
#
# ['nbsp', 'nbsp', 'государь', 'говорить', 'nbsp', 'nbsp', 'это', 'безрассудок']
#
# ['nbsp', 'nbsp', 'плат', 'отвечать', 'nbsp', 'nbsp', 'не', 'знать', 'к', 'что', 'отнести', 'но', 'спорить', 'не', 'сметь', 'и', 'должный', 'молчать']
#
# ['nbsp', 'nbsp', 'а', 'англичанин', 'видеть', 'между', 'государь', 'такой', 'перемолвка', 'сейчас', 'подвести', 'он', 'к', 'самый', 'аболон', 'полведерский', 'и', 'брать', 'у', 'тот', 'из', 'один', 'рука', 'мортимеров', 'ружьё', 'а', 'из', 'другой', 'пистоль']
#
# ['nbsp', 'nbsp', 'вот', 'говорить', 'какой', 'у', 'мы', 'производительность', 'и', 'подавать', 'ружьё']
#
# ['nbsp', 'nbsp', 'государь', 'на', 'мортимеров', 'ружьё', 'посмотреть', 'спокойно', 'потому', 'что', 'у', 'он', 'такой', 'в', 'царский', 'село', 'быть', 'а', 'он', 'потом', 'давать', 'он', 'пистоль', 'и', 'говорить', 'nbsp', 'nbsp', 'это', 'пистоль', 'неизвестный', 'неподражаемый', 'мастерство', 'он', 'наш', 'адмирал', 'у', 'разбойничий', 'атаман', 'в', 'канделабрия', 'пояс', 'выдернуть']
#
# ['nbsp', 'nbsp', 'государь', 'взглянуть', 'на', 'пистоль', 'и', 'наглядеться', 'не', 'мочь']
#
# ['nbsp', 'nbsp', 'взахаться', 'ужасно']
#
# ['nbsp', 'nbsp', 'ах', 'ах', 'ах', 'говорить', 'как', 'это', 'так', 'как', 'это', 'даже', 'можно', 'так', 'тонко', 'сделать']
#
# ['и', 'к', 'платов', 'оборачиваться', 'и', 'говорить', 'вот', 'если', 'бы', 'у', 'я', 'быть', 'хотя', 'один', 'такой', 'мастер', 'в', 'россия', 'так', 'я', 'бы', 'это', 'весьма', 'счастливый', 'быть', 'и', 'гордиться', 'а', 'тот', 'мастер', 'сейчас', 'же', 'благородный', 'бы', 'сделать']
#
# ['nbsp', 'nbsp', 'а', 'плат', 'на', 'этот', 'слово', 'в', 'тот', 'же', 'минута', 'опустить', 'правый', 'рука', 'в', 'свой', 'больший', 'шаровары', 'и', 'тащить', 'оттуда', 'ружейный', 'отвёртка']
#
# ['англичанин', 'говорить', 'это', 'не', 'отворяться', 'а', 'он', 'внимание', 'не', 'обращать', 'ну', 'замок', 'ковырять']
#
# ['повернуть', 'раз', 'повернуть', 'два', 'замок', 'и', 'вынуться']
#
# ['плат', 'показывать', 'государь', 'собачка', 'а', 'там', 'на', 'самый', 'сугиб', 'сделанный', 'русский', 'надпись', 'иван', 'москвин', 'в', 'град', 'тула']
#
# ['nbsp', 'nbsp', 'англичанин', 'удивляться', 'и', 'друг', 'дружка', 'поталкивать', 'nbsp', 'nbsp', 'мы', 'мах', 'дать']
#
# ['nbsp', 'nbsp', 'а', 'государь', 'платов', 'грустно', 'говорить', 'nbsp', 'nbsp', 'зачем', 'ты', 'он', 'очень', 'сконфузить', 'я', 'он', 'теперь', 'очень', 'жалкий']
#
# ['поехать']
#
# ['nbsp', 'nbsp', 'сесть', 'опять', 'в', 'тот', 'же', 'двухсестный', 'карета', 'и', 'поехать', 'и', 'государь', 'в', 'этот', 'день', 'на', 'бал', 'быть', 'а', 'плат', 'ещё', 'стакан', 'кислярка', 'выдушить', 'и', 'спасть', 'крепкий', 'казачий', 'сон']
#
# ['nbsp', 'nbsp', 'быть', 'он', 'и', 'радостный', 'что', 'он', 'англичанин', 'оконфузить', 'а', 'тульский', 'мастер', 'на', 'точка', 'вид', 'поставить', 'но', 'быть', 'и', 'досадный', 'зачем', 'государь', 'под', 'такой', 'случай', 'англичанин', 'сожалеть']
#
# ['nbsp', 'nbsp', 'через', 'что', 'это', 'государь', 'огорчиться']
#
# ['думать', 'плат', 'совсем', 'тот', 'не', 'понимать', 'и', 'в', 'такой', 'рассуждение', 'он', 'два', 'раз', 'вставать', 'креститься', 'и', 'водка', 'пить', 'пока', 'насильно', 'на', 'себя', 'крепкий', 'сон', 'навести']
#
# ['nbsp', 'nbsp', 'а', 'англичанин', 'же', 'в', 'этот', 'самый', 'время', 'тоже', 'не', 'спасть', 'потому', 'что', 'и', 'он', 'завертеть']
#
# ['пока', 'государь', 'на', 'бал', 'веселиться', 'он', 'он', 'такой', 'новый', 'удивление', 'подстроить', 'что', 'у', 'платов', 'весь', 'фантазия', 'отнять']
#
# ['nbsp', 'nbsp', 'глава', 'три', 'nbsp', 'nbsp', 'на', 'другой', 'день', 'как', 'плат', 'к', 'государь', 'с', 'добрый', 'утро', 'явиться', 'то', 'он', 'и', 'говорить', 'nbsp', 'nbsp', 'пусть', 'сейчас', 'заложить', 'двухсестный', 'карета', 'и', 'поехать', 'в', 'новый', 'кунсткамера', 'смотреть']
#
# ['nbsp', 'nbsp', 'плат', 'даже', 'осмелиться', 'доложить', 'что', 'не', 'довольно', 'ли', 'мол', 'чужеземный', 'продукт', 'смотреть', 'и', 'не', 'хороший', 'ли', 'к', 'себя', 'в', 'россия', 'собираться', 'но', 'государь', 'говорить', 'nbsp', 'nbsp', 'нет', 'я', 'ещё', 'желать', 'другой', 'новость', 'видеть', 'я', 'хвалить', 'как', 'у', 'он', 'один', 'сорт', 'сахар', 'делать']
#
# ['nbsp', 'nbsp', 'поехать']
#
# ['nbsp', 'nbsp', 'англичанин', 'всє', 'государь', 'показывать', 'какой', 'у', 'он', 'разный', 'один', 'сорт', 'а', 'плат', 'смотреть', 'смотреть', 'да', 'вдруг', 'говорить', 'nbsp', 'nbsp', 'а', 'мы', 'ваш', 'завод', 'сахар', 'молвый']
#
# ['nbsp', 'nbsp', 'а', 'англичанин', 'и', 'не', 'знать', 'что', 'это', 'такой', 'молво']
#
# ['перешёптываться', 'перемигиваться', 'твердить', 'друг', 'дружка', 'молво', 'молво', 'а', 'понять', 'не', 'мочь', 'что', 'это', 'у', 'мы', 'такой', 'сахар', 'делаться', 'и', 'должный', 'сознаться', 'что', 'у', 'он', 'весь', 'сахар', 'быть', 'а', 'молва', 'нет']
#
# ['nbsp', 'nbsp', 'плат', 'говорить', 'nbsp', 'nbsp', 'ну', 'так', 'и', 'нечего', 'хвастаться']
#
# ['приезжать', 'к', 'мы', 'мы', 'вы', 'напоить', 'чай', 'с', 'настоящий', 'молво', 'бобринский', 'завод']
#
# ['nbsp', 'nbsp', 'а', 'государь', 'он', 'за', 'рукав', 'дёрнуть', 'и', 'тихо', 'сказать', 'nbsp', 'nbsp', 'пожалуйста', 'не', 'портить', 'я', 'политика']
#
# ['nbsp', 'nbsp', 'тогда', 'англичанин', 'позвать', 'государь', 'в', 'самый', 'последний', 'кунсткамера', 'где', 'у', 'он', 'со', 'весь', 'свет', 'собранный', 'минеральный', 'камень', 'и', 'нимфозорий', 'начинать', 'с', 'самый', 'огромный', 'египетский', 'керамид', 'до', 'закожный', 'блоха', 'который', 'глаз', 'видеть', 'невозможный', 'а', 'угрызение', 'он', 'между', 'кожа', 'и', 'тело']
#
# ['nbsp', 'nbsp', 'государь', 'поехать']
#
# ['nbsp', 'nbsp', 'осмотреть', 'керамид', 'и', 'всякий', 'чучел', 'и', 'выходить', 'вон', 'а', 'плат', 'думать', 'себя', 'nbsp', 'nbsp', 'вот', 'слава', 'бог', 'весь', 'благополучный', 'государь', 'ничто', 'не', 'удивляться']
#
# ['nbsp', 'nbsp', 'но', 'только', 'прийти', 'в', 'самый', 'последний', 'комната', 'а', 'тут', 'стоять', 'он', 'рабочий', 'в', 'тужурный', 'жилетка', 'и', 'в', 'фартук', 'и', 'держать', 'поднос', 'на', 'который', 'ничто', 'нет']
#
# ['nbsp', 'nbsp', 'государь', 'вдруг', 'и', 'удивиться', 'что', 'он', 'подавать', 'пустой', 'поднос']
#
# ['nbsp', 'nbsp', 'что', 'это', 'такой', 'значить']
#
# ['спрашивать', 'а', 'аглицкий', 'мастер', 'отвечать', 'nbsp', 'nbsp', 'это', 'ваш', 'величество', 'наш', 'покорный', 'поднесение']
#
# ['nbsp', 'nbsp', 'что', 'же', 'это']
#
# ['nbsp', 'nbsp', 'а', 'вот', 'говорить', 'изволить', 'видеть', 'сориночка']
#
# ['nbsp', 'nbsp', 'государь', 'посмотреть', 'и', 'видеть', 'точно', 'лежать', 'на', 'серебряный', 'поднос', 'самый', 'крошечный', 'соринка']
#
# ['nbsp', 'nbsp', 'работник', 'говорить', 'nbsp', 'nbsp', 'изволить', 'пальчик', 'послюнить', 'и', 'он', 'на', 'ладошка', 'взять']
#
# ['nbsp', 'nbsp', 'на', 'что', 'же', 'я', 'этот', 'соринка']
#
# ['nbsp', 'nbsp', 'это', 'отвечать', 'не', 'соринка', 'а', 'нимфозорий']
#
# ['nbsp', 'nbsp', 'живой', 'он']
#
# ['nbsp', 'nbsp', 'никак', 'нет', 'отвечать', 'не', 'живой', 'а', 'из', 'чистый', 'из', 'аглицкий', 'сталь', 'в', 'изображение', 'блоха', 'мы', 'выкованный', 'и', 'в', 'середина', 'в', 'он', 'завод', 'и', 'пружина']
#
# ['изволить', 'ключик', 'повернуть', 'он', 'сейчас', 'начать', 'данс', 'танцевать']
#
# ['nbsp', 'nbsp', 'государь', 'залюбопытствовать', 'и', 'спрашивать', 'nbsp', 'nbsp', 'а', 'где', 'же', 'ключик']
#
# ['nbsp', 'nbsp', 'а', 'англичанин', 'говорить', 'nbsp', 'nbsp', 'здесь', 'и', 'ключ', 'перед', 'ваш', 'око']
#
# ['nbsp', 'nbsp', 'отчего', 'же', 'государь', 'говорить', 'я', 'он', 'не', 'видеть']
#
# ['nbsp', 'nbsp', 'потому', 'отвечать', 'что', 'это', 'надо', 'в', 'мелкоскоп']
#
# ['nbsp', 'nbsp', 'подать', 'мелкоскоп', 'и', 'государь', 'увидеть', 'что', 'возле', 'блоха', 'действительно', 'на', 'поднос', 'ключик', 'лежать']
#
# ['nbsp', 'nbsp', 'изволить', 'говорить', 'взять', 'он', 'на', 'ладошечка', 'у', 'он', 'в', 'пузичка', 'заводной', 'дырка', 'а', 'ключ', 'семь', 'поворот', 'иметь', 'и', 'тогда', 'он', 'пойти', 'данс', 'nbsp', 'nbsp', 'насилу', 'государь', 'этот', 'ключик', 'ухватить', 'и', 'насилу', 'он', 'в', 'щепотка', 'мочь', 'удержать', 'а', 'в', 'другой', 'щепотка', 'блошка', 'взять', 'и', 'только', 'ключик', 'вставить', 'как', 'почувствовать', 'что', 'он', 'начинать', 'усик', 'водить', 'потом', 'ножка', 'стать', 'перебирать', 'а', 'наконец', 'вдруг', 'прыгнуть', 'и', 'на', 'один', 'лёт', 'прямой', 'данс', 'и', 'два', 'верояция', 'в', 'сторона', 'потом', 'в', 'другой', 'и', 'так', 'в', 'три', 'верояция', 'весь', 'кавриль', 'станцевать']
#
# ['nbsp', 'nbsp', 'государь', 'сразу', 'же', 'велеть', 'англичанин', 'миллион', 'дать', 'какой', 'сам', 'захотеть', 'деньга', 'хотеть', 'серебряный', 'пятачок', 'хотеть', 'мелкий', 'ассигнация']
#
# ['nbsp', 'nbsp', 'англичанин', 'попросить', 'чтобы', 'он', 'серебро', 'отпустить', 'потому', 'что', 'в', 'бумажка', 'он', 'толк', 'не', 'знать', 'а', 'потом', 'сейчас', 'и', 'другой', 'свой', 'хитрость', 'показать', 'блоха', 'в', 'дар', 'подать', 'а', 'футляр', 'на', 'он', 'не', 'принести', 'без', 'футляр', 'же', 'ни', 'он', 'ни', 'ключик', 'держать', 'нельзя', 'потому', 'что', 'затеряться', 'и', 'в', 'сор', 'он', 'так', 'и', 'выбросить']
#
# ['а', 'футляр', 'на', 'он', 'у', 'он', 'сделанный', 'из', 'цельный', 'бриллиантовый', 'орех', 'а', 'и', 'он', 'местечко', 'в', 'середина', 'выдавленный']
#
# ['это', 'он', 'не', 'подать', 'потому', 'что', 'футляр', 'говорить', 'будто', 'казённый', 'а', 'у', 'он', 'насчёт', 'казённый', 'строго', 'хоть', 'и', 'для', 'государь', 'нельзя', 'жертвовать']
#
# ['nbsp', 'nbsp', 'плат', 'быть', 'очень', 'рассердиться', 'потому', 'что', 'говорить', 'nbsp', 'nbsp', 'для', 'что', 'такой', 'мошенничество']
#
# ['дар', 'сделать', 'и', 'миллион', 'за', 'то', 'получить', 'и', 'весь', 'ещё', 'недостаточный']
#
# ['футляр', 'говорить', 'всегда', 'при', 'всякий', 'вещь', 'принадлежать']
#
# ['nbsp', 'nbsp', 'но', 'государь', 'говорить', 'nbsp', 'nbsp', 'оставить', 'пожалуйста', 'это', 'не', 'твой', 'дело', 'не', 'портить', 'я', 'политика']
#
# ['у', 'он', 'свой', 'и', 'спрашивать', 'сколько', 'то', 'орех', 'стоять', 'в', 'который', 'блоха', 'меститься']
#
# ['nbsp', 'nbsp', 'англичанин', 'положить', 'за', 'это', 'ещё', 'пять', 'тысяча']
#
# ['nbsp', 'nbsp', 'государь', 'александр', 'павло', 'сказать', 'выплатить', 'а', 'сам', 'опустить', 'блошка', 'в', 'этот', 'орешек', 'а', 'с', 'он', 'вместе', 'и', 'ключик', 'а', 'чтобы', 'не', 'потерять', 'самый', 'орех', 'опустить', 'он', 'в', 'свой', 'золотой', 'табакерка', 'а', 'табакерка', 'велеть', 'положить', 'в', 'свой', 'дорожный', 'шкатулка', 'который', 'весь', 'выстланный', 'преламут', 'и', 'рыбий', 'кость']
#
# ['аглицкий', 'же', 'мастер', 'государь', 'с', 'честь', 'отпустить', 'и', 'сказать', 'он', 'вы', 'быть', 'один', 'мастер', 'на', 'весь', 'свет', 'и', 'мой', 'человек', 'супротив', 'вы', 'сделать', 'ничто', 'не', 'мочь']
#
# ['nbsp', 'nbsp', 'тот', 'остаться', 'это', 'очень', 'довольный', 'а', 'плат', 'ничто', 'против', 'слово', 'государь', 'произнести', 'не', 'мочь']
#
# ['только', 'взять', 'мелкоскоп', 'да', 'ничто', 'не', 'говорить', 'себя', 'в', 'карман', 'спустить', 'потому', 'что', 'он', 'сюда', 'же', 'говорить', 'принадлежать', 'а', 'деньга', 'вы', 'и', 'без', 'тот', 'у', 'мы', 'много', 'взять']
#
# ['nbsp', 'nbsp', 'государь', 'это', 'не', 'знать', 'до', 'самый', 'приезд', 'в', 'россия', 'а', 'уехать', 'он', 'скоро', 'потому', 'что', 'у', 'государь', 'от', 'военный', 'дело', 'сделаться', 'меланхолия', 'и', 'он', 'захотеть', 'духовный', 'исповедь', 'иметь', 'в', 'таганрог', 'у', 'поп', 'федот', 'поп', 'федот', 'не', 'с', 'ветер', 'взятый', 'император', 'александр', 'павло', 'перед', 'свой', 'кончина', 'в', 'таганрог', 'исповедоваться', 'у', 'священник', 'алексей', 'который', 'после', 'тот', 'именоваться', 'духовник', 'он', 'величество', 'и', 'любить', 'ставить', 'весь', 'на', 'вид', 'этот', 'совершенно', 'случайный', 'обстоятельство']
#
# ['вот', 'очевидно', 'и', 'быть', 'легендарный', 'поп', 'федот']
#
# ['прима']
#
# ['автор']
#
# []
#
# ['дорога', 'у', 'он', 'с', 'платов', 'очень', 'мало', 'приятный', 'разговор', 'быть', 'потому', 'он', 'совсем', 'разный', 'мысль', 'сделаться', 'государь', 'так', 'соображать', 'что', 'англичанин', 'нет', 'равный', 'в', 'искусство', 'а', 'плат', 'доводить', 'что', 'и', 'наш', 'на', 'что', 'взглянуть', 'всє', 'мочь', 'сделать', 'но', 'только', 'он', 'полезный', 'учение', 'нет']
#
# ['и', 'представлять', 'государь', 'что', 'у', 'аглицкий', 'мастер', 'совсем', 'на', 'весь', 'другой', 'правило', 'жизнь', 'наука', 'и', 'продовольствие', 'и', 'каждый', 'человек', 'у', 'он', 'себя', 'весь', 'абсолютный', 'обстоятельство', 'перед', 'себя', 'иметь', 'и', 'через', 'то', 'в', 'он', 'совсем', 'другой', 'смысл']
#
# ['nbsp', 'nbsp', 'государь', 'это', 'не', 'хотеть', 'долго', 'слушать', 'а', 'плат', 'видеть', 'это', 'не', 'стать', 'усиливаться']
#
# ['так', 'он', 'и', 'ехать', 'молча', 'только', 'плат', 'на', 'каждый', 'станция', 'выйти', 'и', 'с', 'досада', 'квасной', 'стакан', 'водка', 'выпить', 'солёный', 'бараночек', 'закусить', 'закурить', 'свой', 'корешковый', 'трубка', 'в', 'который', 'сразу', 'целый', 'фунт', 'жуков', 'табак', 'входить', 'а', 'потом', 'сесть', 'и', 'сидеть', 'ряд', 'с', 'царь', 'в', 'карета', 'молча']
#
# ['государь', 'в', 'один', 'сторона', 'глядеть', 'а', 'плат', 'в', 'другой', 'окно', 'чубук', 'высунуть', 'и', 'дымить', 'на', 'ветер']
#
# ['так', 'он', 'и', 'доехать', 'до', 'петербург', 'а', 'к', 'поп', 'федот', 'государь', 'платов', 'уже', 'совсем', 'не', 'взять']
#
# ['nbsp', 'nbsp', 'ты', 'говорить', 'к', 'духовный', 'беседа', 'невоздержный', 'и', 'так', 'очень', 'много', 'курить', 'что', 'у', 'я', 'от', 'твой', 'дым', 'в', 'голова', 'копоть', 'стоять']
#
# ['nbsp', 'nbsp', 'плат', 'остаться', 'с', 'обида', 'и', 'лечь', 'дом', 'на', 'досадный', 'укушетка', 'да', 'так', 'весь', 'и', 'лежать', 'да', 'покуривать', 'жук', 'табак', 'без', 'перестача']
#
# ['nbsp', 'nbsp', 'глава', 'четыре', 'nbsp', 'nbsp', 'удивительный', 'блоха', 'из', 'аглицкий', 'воронёный', 'сталь', 'оставаться', 'у', 'александр', 'павло', 'в', 'шкатулка', 'под', 'рыбий', 'кость', 'пока', 'он', 'скончаться', 'в', 'таганрог', 'отдать', 'он', 'попа', 'федот', 'чтобы', 'сдать', 'после', 'государыня', 'когда', 'он', 'успокоиться']
#
# ['императрица', 'елисавета', 'алексей', 'посмотреть', 'блохин', 'верояция', 'и', 'усмехнуться', 'но', 'заниматься', 'он', 'не', 'стать']
#
# ['nbsp', 'nbsp', 'мой', 'говорить', 'теперь', 'дело', 'вдовий', 'и', 'я', 'никакой', 'забава', 'не', 'обольстительный', 'а', 'вернуться', 'в', 'петербург', 'передать', 'этот', 'диковина', 'со', 'весь', 'иной', 'драгоценность', 'в', 'наследство', 'новый', 'государь']
#
# ['nbsp', 'nbsp', 'император', 'николай', 'павло', 'поначалу', 'тоже', 'никакой', 'внимание', 'на', 'блоха', 'не', 'обратить', 'потому', 'что', 'при', 'восход', 'он', 'быть', 'смятение', 'но', 'потом', 'один', 'раз', 'стать', 'пересматривать', 'доставшийся', 'он', 'от', 'брат', 'шкатулка', 'и', 'достать', 'из', 'он', 'табакерка', 'а', 'из', 'табакерка', 'бриллиантовый', 'орех', 'и', 'в', 'он', 'найти', 'стальной', 'блоха', 'который', 'уже', 'давно', 'не', 'быть', 'заведённый', 'и', 'потому', 'не', 'действовать', 'а', 'лежать', 'смирно', 'как', 'коченелый']
#
# ['nbsp', 'nbsp', 'государь', 'посмотреть', 'и', 'удивиться']
#
# ['nbsp', 'nbsp', 'что', 'это', 'ещё', 'за', 'пустяковина', 'и', 'к', 'что', 'он', 'тут', 'у', 'мой', 'брат', 'в', 'такой', 'сохранение']
#
# ['nbsp', 'nbsp', 'придворный', 'хотеть', 'выбросить', 'но', 'государь', 'говорить', 'nbsp', 'nbsp', 'нет', 'это', 'значить']
#
# ['nbsp', 'nbsp', 'позвать', 'от', 'аничкин', 'мост', 'из', 'противный', 'аптека', 'химик', 'который', 'на', 'самый', 'мелкий', 'вес', 'яд', 'взвешивать', 'и', 'он', 'показать', 'а', 'то', 'сейчас', 'взять', 'блоха', 'положить', 'на', 'язык', 'и', 'говорить', 'чувствовать', 'хлад', 'как', 'от', 'крепкий', 'металл']
#
# ['а', 'потом', 'зуб', 'он', 'слегка', 'помять', 'и', 'объявить', 'nbsp', 'nbsp', 'как', 'вы', 'угодно', 'а', 'это', 'не', 'настоящий', 'блоха', 'а', 'нимфозорий', 'и', 'он', 'сотворённый', 'из', 'металл', 'и', 'работа', 'этот', 'не', 'наш', 'не', 'русский']
#
# ['nbsp', 'nbsp', 'государь', 'велеть', 'сейчас', 'разузнать', 'откуда', 'это', 'и', 'что', 'такой', 'означать']
#
# ['nbsp', 'nbsp', 'броситься', 'смотреть', 'в', 'дело', 'и', 'в', 'список', 'но', 'в', 'дело', 'ничто', 'не', 'записанный']
#
# ['стать', 'тот', 'другой', 'спрашивать', 'никто', 'ничто', 'не', 'знать']
#
# ['но', 'по', 'счастие', 'донской', 'казак', 'плат', 'быть', 'ещё', 'живой', 'и', 'даже', 'весь', 'ещё', 'на', 'свой', 'досадный', 'укушетка', 'лежать', 'и', 'трубка', 'курить']
#
# ['он', 'как', 'услыхать', 'что', 'в', 'дворец', 'такой', 'беспокойство', 'сейчас', 'с', 'укушетка', 'подняться', 'трубка', 'бросить', 'и', 'явиться', 'к', 'государь', 'в', 'весь', 'орден']
#
# ['государь', 'говорить', 'nbsp', 'nbsp', 'что', 'ты', 'мужественный', 'старик', 'от', 'я', 'надобный']
#
# ['nbsp', 'nbsp', 'а', 'плат', 'отвечать', 'nbsp', 'nbsp', 'я', 'ваш', 'величество', 'ничто', 'для', 'себя', 'не', 'надо', 'так', 'как', 'я', 'что', 'хотеть', 'и', 'весь', 'довольный', 'а', 'я', 'говорить', 'прийти', 'доложить', 'насчёт', 'этот', 'нимфозорий', 'который', 'отыскать', 'это', 'говорить', 'так', 'и', 'так', 'быть', 'и', 'вот', 'как', 'происходить', 'при', 'мой', 'глаз', 'в', 'англия', 'и', 'тут', 'при', 'он', 'быть', 'ключик', 'а', 'у', 'я', 'быть', 'он', 'же', 'мелкоскоп', 'в', 'который', 'можно', 'он', 'видеть', 'и', 'сей', 'ключ', 'через', 'пузичко', 'этот', 'нимфозорию', 'можно', 'завести', 'и', 'он', 'быть', 'скакать', 'в', 'какой', 'угодно', 'пространство', 'и', 'в', 'сторона', 'верояция', 'делать']
#
# ['nbsp', 'nbsp', 'завести', 'он', 'и', 'пойти', 'прыгать', 'а', 'плат', 'говорить', 'nbsp', 'nbsp', 'это', 'говорить', 'ваш', 'величество', 'точный', 'что', 'работа', 'очень', 'тонкий', 'и', 'интересный', 'но', 'только', 'мы', 'это', 'удивляться', 'с', 'один', 'восторг', 'чувство', 'не', 'следовать', 'а', 'надо', 'бы', 'подвергнуть', 'он', 'русский', 'пересмотр', 'в', 'тула', 'или', 'в', 'сестербек', 'тогда', 'ещё', 'сестрорецк', 'сестербек', 'звать', 'не', 'мочь', 'ли', 'наш', 'мастер', 'сей', 'превзойти', 'чтобы', 'англичанин', 'над', 'русский', 'не', 'предвозвышаться']
#
# ['nbsp', 'nbsp', 'государь', 'николай', 'павло', 'в', 'свой', 'русский', 'человек', 'быть', 'очень', 'уверенный', 'и', 'никакой', 'иностранец', 'уступать', 'не', 'любить', 'он', 'и', 'ответить', 'платов', 'nbsp', 'nbsp', 'это', 'ты', 'мужественный', 'старик', 'хорошо', 'говорить', 'и', 'я', 'ты', 'этот', 'дело', 'поручать', 'поверить']
#
# ['я', 'этот', 'коробочка', 'весь', 'равно', 'теперь', 'при', 'мой', 'хлопоты', 'не', 'нужный', 'а', 'ты', 'взять', 'он', 'с', 'себя', 'и', 'на', 'свой', 'досадный', 'укушетка', 'большой', 'не', 'ложиться', 'а', 'поехать', 'на', 'тихий', 'дон', 'и', 'повести', 'там', 'с', 'мой', 'донце', 'междоусобный', 'разговор', 'насчёт', 'он', 'жизнь', 'и', 'преданность', 'и', 'что', 'он', 'нравиться']
#
# ['а', 'когда', 'быть', 'ехать', 'через', 'тула', 'показать', 'мой', 'тульский', 'мастер', 'этот', 'нимфозорий', 'и', 'пусть', 'он', 'о', 'он', 'подумать']
#
# ['сказать', 'он', 'от', 'я', 'что', 'брат', 'мой', 'этот', 'вещь', 'удивляться', 'и', 'чужой', 'человек', 'который', 'делать', 'нимфозорий', 'большой', 'весь', 'хвалить', 'а', 'я', 'на', 'свой', 'надеяться', 'что', 'он', 'никто', 'не', 'худой']
#
# ['он', 'мой', 'слово', 'не', 'проронить', 'и', 'сделать']
#
# ['nbsp', 'nbsp', 'глава', 'пять', 'nbsp', 'nbsp', 'плат', 'взять', 'стальной', 'блоха', 'и', 'как', 'поехать', 'через', 'тула', 'на', 'дон', 'показать', 'он', 'тульский', 'оружейник', 'и', 'слово', 'государев', 'он', 'передать', 'а', 'потом', 'спрашивать', 'nbsp', 'nbsp', 'как', 'мы', 'теперь', 'быть', 'православный']
#
# ['nbsp', 'nbsp', 'оружейник', 'отвечать', 'nbsp', 'nbsp', 'мы', 'батюшка', 'милостивый', 'слово', 'государев', 'чувствовать', 'и', 'никогда', 'он', 'забыть', 'не', 'мочь', 'за', 'то', 'что', 'он', 'на', 'свой', 'человек', 'надеяться', 'а', 'как', 'мы', 'в', 'настоящий', 'случай', 'быть', 'тот', 'мы', 'в', 'один', 'минута', 'сказать', 'не', 'мочь', 'потому', 'что', 'аглицкий', 'нацый', 'тоже', 'не', 'глупый', 'а', 'довольно', 'даже', 'хитрый', 'и', 'искусство', 'в', 'он', 'с', 'больший', 'смысл']
#
# ['против', 'он', 'говорить', 'надо', 'взяться', 'подумать', 'и', 'с', 'божий', 'благословение']
#
# ['а', 'ты', 'если', 'твой', 'милость', 'как', 'и', 'государь', 'наш', 'иметь', 'к', 'мы', 'доверие', 'поехать', 'к', 'себя', 'на', 'тихий', 'дон', 'а', 'мы', 'этот', 'блошка', 'оставить', 'как', 'он', 'быть', 'в', 'футляр', 'и', 'в', 'золотой', 'царский', 'табакерочка']
#
# ['гулять', 'себя', 'по', 'дон', 'и', 'заживлять', 'рана', 'который', 'принять', 'за', 'отечество', 'а', 'когда', 'назад', 'быть', 'через', 'тула', 'ехать', 'остановиться', 'и', 'спосылай', 'за', 'мы', 'мы', 'к', 'тот', 'пора', 'бог', 'дать', 'придумать']
#
# ['nbsp', 'nbsp', 'плат', 'не', 'совсем', 'довольный', 'быть', 'тем', 'что', 'туляк', 'так', 'много', 'время', 'требовать', 'и', 'притом', 'не', 'говорить', 'ясно', 'что', 'такой', 'именно', 'он', 'надеяться', 'устроить']
#
# ['спрашивать', 'он', 'он', 'так', 'и', 'иначе', 'и', 'на', 'весь', 'манера', 'с', 'он', 'хитро', 'заговаривать', 'но', 'туляк', 'он', 'в', 'хитрость', 'нимало', 'не', 'уступить', 'потому', 'что', 'иметь', 'он', 'сразу', 'же', 'такой', 'замысел', 'по', 'который', 'не', 'надеяться', 'даже', 'чтобы', 'и', 'плат', 'он', 'поверить', 'а', 'хотеть', 'прямо', 'свой', 'смелый', 'воображение', 'исполнить', 'да', 'тогда', 'и', 'отдать']
#
# ['nbsp', 'nbsp', 'говорить', 'nbsp', 'nbsp', 'мы', 'ещё', 'и', 'сам', 'не', 'знать', 'что', 'учинить', 'а', 'только', 'быть', 'на', 'бог', 'надеяться', 'и', 'авось', 'слово', 'царский', 'ради', 'мы', 'в', 'постыждение', 'не', 'быть']
#
# ['nbsp', 'nbsp', 'так', 'и', 'плат', 'ум', 'вилять', 'и', 'туляк', 'тоже']
#
# ['nbsp', 'nbsp', 'плат', 'вилять', 'вилять', 'да', 'увидать', 'что', 'туляк', 'он', 'не', 'перевилять', 'подать', 'он', 'табакерка', 'с', 'нимфозория', 'и', 'говорить', 'nbsp', 'nbsp', 'ну', 'нечего', 'делать', 'пусть', 'говорить', 'быть', 'я', 'вы', 'знать', 'какой', 'вы', 'ну', 'однач', 'делать', 'нечего', 'я', 'вы', 'верить', 'но', 'только', 'смотреть', 'бриллиант', 'чтобы', 'не', 'подменить', 'и', 'аглицкий', 'тонкий', 'работа', 'не', 'испортить', 'да', 'недолго', 'возиться', 'потому', 'что', 'я', 'шибко', 'ездить', 'два', 'неделя', 'не', 'пройти', 'как', 'я', 'с', 'тихий', 'дон', 'опять', 'в', 'петербург', 'поворотить', 'тогда', 'я', 'чтоб', 'непременно', 'быть', 'что', 'государь', 'показать']
#
# ['nbsp', 'nbsp', 'оружейник', 'он', 'вполне', 'успокоить', 'nbsp', 'nbsp', 'тонкий', 'работа', 'говорить', 'мы', 'не', 'повредить', 'и', 'бриллиант', 'не', 'обменить', 'а', 'два', 'неделя', 'мы', 'время', 'довольно', 'а', 'к', 'тот', 'случай', 'когда', 'назад', 'возвратиться', 'быть', 'ты', 'государев', 'великолепие', 'достойный', 'представить']
#
# ['nbsp', 'nbsp', 'а', 'что', 'именно', 'это', 'и', 'не', 'сказать']
#
# ['nbsp', 'nbsp', 'глава', 'шесть', 'nbsp', 'nbsp', 'плат', 'из', 'тула', 'уехать', 'а', 'оружейник', 'три', 'человек', 'самый', 'искусный', 'из', 'он', 'один', 'косой', 'левша', 'на', 'щека', 'пятно', 'родимый', 'а', 'на', 'висок', 'волосие', 'при', 'учение', 'выдранный', 'попрощаться', 'с', 'товарищ', 'и', 'с', 'свой', 'домашние', 'да', 'ничто', 'никто', 'не', 'сказывать', 'взять', 'сумочка', 'положить', 'туда', 'что', 'нужный', 'съестной', 'и', 'скрыться', 'из', 'город']
#
# ['nbsp', 'nbsp', 'заметить', 'за', 'он', 'только', 'то', 'что', 'он', 'пойти', 'не', 'в', 'московский', 'застава', 'а', 'в', 'противоположный', 'киевский', 'сторона', 'и', 'думать', 'что', 'он', 'пойти', 'в', 'кий', 'почивающий', 'угодник', 'поклониться', 'или', 'посоветовать', 'там', 'с', 'из', 'живой', 'святой', 'муж', 'всегда', 'пребывающий', 'в', 'киев', 'в', 'изобилие']
#
# ['nbsp', 'nbsp', 'но', 'это', 'быть', 'только', 'близкий', 'к', 'истина', 'а', 'не', 'самый', 'истина']
#
# ['ни', 'время', 'ни', 'расстояние', 'не', 'дозволять', 'тульский', 'мастер', 'сходить', 'в', 'три', 'неделя', 'пешком', 'в', 'кий', 'да', 'ещё', 'потом', 'успеть', 'сделать', 'посрамительный', 'для', 'аглицкий', 'нация', 'работа']
#
# ['хороший', 'бы', 'он', 'мочь', 'сходить', 'помолиться', 'в', 'москва', 'до', 'который', 'всего', 'два', 'девяносто', 'верста', 'а', 'святой', 'угодник', 'и', 'там', 'почивать', 'немало']
#
# ['а', 'в', 'другой', 'сторона', 'до', 'орёл', 'такой', 'же', 'два', 'девяносто', 'да', 'за', 'орёл', 'до', 'киев', 'снова', 'ещё', 'добрый', 'пять', 'соты', 'верста']
#
# ['этакий', 'путь', 'скоро', 'не', 'сделать', 'да', 'и', 'сделать', 'он', 'не', 'скоро', 'отдохнуть', 'долго', 'ещё', 'быть', 'нога', 'остеклить', 'и', 'рука', 'трястись']
#
# ['nbsp', 'nbsp', 'иной', 'даже', 'думаться', 'что', 'мастер', 'набахвалить', 'перед', 'платов', 'а', 'потом', 'как', 'пообдуматься', 'то', 'и', 'струсить', 'и', 'теперь', 'совсем', 'сбежать', 'унести', 'с', 'себя', 'и', 'царский', 'золотой', 'табакерка', 'и', 'бриллиант', 'и', 'наделавший', 'он', 'хлопоты', 'аглицкий', 'стальной', 'блоха', 'в', 'футляр']
#
# ['nbsp', 'nbsp', 'однако', 'такой', 'предположение', 'быть', 'тоже', 'совершенно', 'неосновательный', 'и', 'недостойный', 'искусный', 'человек', 'на', 'который', 'теперь', 'почивать', 'надежда', 'нация']
#
# ['nbsp', 'nbsp', 'глава', 'семь', 'nbsp', 'nbsp', 'туляк', 'человек', 'умный', 'и', 'сведущий', 'в', 'металлический', 'дело', 'известный', 'также', 'как', 'один', 'знаток', 'в', 'религия']
#
# ['он', 'слава', 'в', 'этот', 'отношение', 'полный', 'и', 'родной', 'земля', 'и', 'даже', 'святой', 'афон', 'он', 'не', 'только', 'мастер', 'петь', 'с', 'вавилоны', 'но', 'он', 'знать', 'как', 'писаться', 'картина', 'вечерний', 'звон', 'а', 'если', 'кто', 'из', 'он', 'посвятить', 'себя', 'больший', 'служение', 'и', 'пойти', 'в', 'монашество', 'то', 'таковой', 'слыть', 'хороший', 'монастырский', 'эконом', 'и', 'из', 'он', 'выходить', 'самый', 'способный', 'сборщик']
#
# ['на', 'святой', 'афон', 'знать', 'что', 'туляк', 'народ', 'самый', 'выгодный', 'и', 'если', 'бы', 'не', 'он', 'то', 'тёмный', 'уголок', 'россия', 'наверно', 'не', 'видать', 'бы', 'очень', 'многий', 'святость', 'отдалённый', 'восток', 'а', 'афон', 'лишиться', 'бы', 'многий', 'полезный', 'приношение', 'от', 'русский', 'щедрота', 'и', 'благочестие']
#
# ['теперь', 'афонский', 'туляк', 'обвозить', 'святость', 'по', 'весь', 'наш', 'родина', 'и', 'мастерски', 'собирать', 'сбор', 'даже', 'там', 'где', 'взять', 'нечего']
#
# ['туляк', 'полный', 'церковный', 'благочестие', 'и', 'великий', 'практик', 'этот', 'дело', 'а', 'потому', 'и', 'тот', 'три', 'мастер', 'который', 'взяться', 'поддержать', 'платов', 'и', 'с', 'он', 'весь', 'россия', 'не', 'делать', 'ошибка', 'направиться', 'не', 'к', 'москва', 'а', 'на', 'юг']
#
# ['он', 'идти', 'вовсе', 'не', 'в', 'кий', 'а', 'к', 'мценск', 'к', 'уездный', 'город', 'орловский', 'губерния', 'в', 'который', 'стоять', 'древний', 'камнесеченный', 'икона', 'св']
#
# ['николай', 'приплывший', 'сюда', 'в', 'самый', 'древний', 'время', 'на', 'большой', 'каменный', 'же', 'крест', 'по', 'река', 'зуша']
#
# ['икона', 'этот', 'вид', 'грозный', 'и', 'престрашный', 'святитель', 'изображённый', 'на', 'он', 'в', 'рост', 'весь', 'одеянный', 'сребропозлащенный', 'одежда', 'а', 'лицо', 'тёмный', 'и', 'на', 'один', 'рука', 'держать', 'храм', 'а', 'в', 'другой', 'меч', 'военный', 'одоление']
#
# ['вот', 'в', 'это', 'одоление', 'и', 'заключаться', 'смысл', 'вещь', 'св']
#
# ['николай', 'вообще', 'покровитель', 'торговый', 'и', 'военный', 'дело', 'а', 'мценский', 'никол', 'в', 'особенность', 'и', 'туляк', 'и', 'пойти', 'поклониться']
#
# ['отслужить', 'он', 'молебен', 'у', 'самый', 'икона', 'потом', 'у', 'каменный', 'крест', 'и', 'наконец', 'возвратиться', 'домой', 'нощие', 'и', 'ничто', 'никто', 'не', 'рассказывать', 'приняться', 'за', 'дело', 'в', 'ужасный', 'секрет']
#
# ['сойтись', 'он', 'весь', 'трое', 'в', 'один', 'домик', 'к', 'левша', 'дверь', 'запереть', 'ставня', 'в', 'окно', 'закрыть', 'перед', 'николин', 'образ', 'лампадка', 'затеплить', 'и', 'начать', 'работать']
#
# ['nbsp', 'nbsp', 'день', 'два', 'три', 'сидеть', 'и', 'никуда', 'не', 'выходить', 'весь', 'молоточек', 'потюкивать']
#
# ['ковать', 'такой', 'а', 'что', 'ковать', 'ничто', 'неизвестно']
#
# ['nbsp', 'nbsp', 'весь', 'любопытный', 'а', 'никто', 'ничто', 'не', 'мочь', 'узнать', 'потому', 'что', 'работающий', 'ничто', 'не', 'сказывать', 'и', 'наружу', 'не', 'показываться']
#
# ['ходить', 'к', 'домик', 'разный', 'человек', 'стучаться', 'в', 'дверь', 'под', 'разный', 'вид', 'чтобы', 'огонь', 'или', 'соль', 'попросить', 'но', 'три', 'искусник', 'ни', 'на', 'какой', 'спрос', 'не', 'отпираться', 'и', 'даже', 'что', 'питаться', 'неизвестно']
#
# ['пробовать', 'он', 'пугать', 'будто', 'по', 'соседство', 'дом', 'гореть', 'не', 'выскотать', 'ли', 'в', 'перепуг', 'и', 'не', 'объявиться', 'ли', 'тогда', 'что', 'он', 'выкованный', 'но', 'ничто', 'не', 'брать', 'этот', 'хитрый', 'мастер', 'один', 'раз', 'только', 'левша', 'высунуться', 'по', 'плечо', 'и', 'крикнуть', 'nbsp', 'nbsp', 'гореть', 'себя', 'а', 'мы', 'некогда', 'и', 'опять', 'свой', 'щипаный', 'голова', 'спрятать', 'ставня', 'захлопнуть', 'и', 'за', 'свой', 'дело', 'принялисить']
#
# ['nbsp', 'nbsp', 'только', 'сквозь', 'малый', 'щёлочка', 'быть', 'видный', 'как', 'внутри', 'дом', 'огонёк', 'блестеть', 'да', 'слышный', 'что', 'тонкий', 'молоточек', 'по', 'звонкий', 'наковальня', 'вытюкивать']
#
# ['nbsp', 'nbsp', 'слово', 'весь', 'дело', 'вестись', 'в', 'такой', 'страшный', 'секрет', 'что', 'ничто', 'нельзя', 'быть', 'узнать', 'и', 'притом', 'продолжаться', 'он', 'до', 'самый', 'возвращение', 'казак', 'платов', 'с', 'тихий', 'дон', 'к', 'государь', 'и', 'в', 'весь', 'этот', 'время', 'мастер', 'ни', 'с', 'кто', 'не', 'видаться', 'и', 'не', 'разговаривать']
#
# ['nbsp', 'nbsp', 'глава', 'восемь', 'nbsp', 'nbsp', 'плат', 'ехать', 'очень', 'спешно', 'и', 'с', 'церемония', 'сам', 'он', 'сидеть', 'в', 'коляска', 'а', 'на', 'козёл', 'два', 'свистовой', 'казак', 'с', 'нагайка', 'по', 'оба', 'сторона', 'ямщик', 'садиться', 'и', 'так', 'он', 'и', 'поливать', 'без', 'милосердие', 'чтобы', 'скакать']
#
# ['а', 'если', 'какой', 'казак', 'задремать', 'плат', 'он', 'сам', 'из', 'коляска', 'нога', 'ткнуть', 'и', 'ещё', 'злой', 'понестись']
#
# ['этот', 'мера', 'побуждение', 'действовать', 'до', 'тот', 'успешно', 'что', 'нигде', 'лошадь', 'ни', 'у', 'один', 'станция', 'нельзя', 'быть', 'удержать', 'а', 'всегда', 'сто', 'скачок', 'мимо', 'остановочный', 'место', 'перескакивать']
#
# ['тогда', 'опять', 'казак', 'над', 'ямщик', 'обратно', 'сдействовать', 'и', 'к', 'подъезд', 'возворотиться']
#
# ['nbsp', 'nbsp', 'так', 'он', 'и', 'в', 'тула', 'прикатить', 'тоже', 'пролететь', 'сначала', 'сто', 'скачок', 'далёкий', 'московский', 'застава', 'а', 'потом', 'казак', 'сдействовать', 'над', 'ямщик', 'нагайка', 'в', 'обратный', 'сторона', 'и', 'стать', 'у', 'крыльцо', 'новый', 'конь', 'запрягать']
#
# ['плат', 'же', 'из', 'коляска', 'не', 'выйти', 'а', 'только', 'велеть', 'свистовой', 'как', 'можно', 'скорый', 'привести', 'к', 'себя', 'мастеровой', 'который', 'блоха', 'оставить']
#
# ['nbsp', 'nbsp', 'побежать', 'один', 'свистовой', 'чтобы', 'идти', 'как', 'можно', 'скорый', 'и', 'нести', 'он', 'работа', 'котора', 'должный', 'быть', 'англичанин', 'посрамить', 'и', 'ещё', 'мало', 'этот', 'свистовой', 'отбежать', 'как', 'плат', 'вдогонку', 'за', 'он', 'раз', 'за', 'раз', 'новый', 'слать', 'чтобы', 'как', 'можно', 'скорый']
#
# ['nbsp', 'nbsp', 'весь', 'свистовой', 'разогнать', 'и', 'стать', 'уже', 'простой', 'человек', 'из', 'любопытный', 'публика', 'посылать', 'да', 'даже', 'и', 'сам', 'от', 'нетерпение', 'нога', 'из', 'коляска', 'выставлять', 'и', 'сам', 'от', 'нетерпеливость', 'бежать', 'хотеть', 'а', 'зуб', 'так', 'и', 'скрипеть', 'весь', 'он', 'ещё', 'нескоро', 'показываться']
#
# ['nbsp', 'nbsp', 'так', 'в', 'тогдашний', 'время', 'весь', 'требоваться', 'очень', 'в', 'аккурат', 'и', 'в', 'скорость', 'чтобы', 'ни', 'один', 'минута', 'для', 'русский', 'полезность', 'не', 'пропадать']
#
# ['nbsp', 'nbsp', 'глава', 'девять', 'nbsp', 'nbsp', 'тульский', 'мастер', 'который', 'удивительный', 'дело', 'делать', 'в', 'этот', 'время', 'как', 'раз', 'только', 'свой', 'работа', 'оканчивать']
#
# ['свистовой', 'прибежать', 'к', 'он', 'запыхаться', 'а', 'простой', 'человек', 'из', 'любопытный', 'публика', 'тот', 'и', 'вовсе', 'не', 'добежать', 'потому', 'что', 'с', 'непривычка', 'по', 'дорога', 'нога', 'рассыпать', 'и', 'повалиться', 'а', 'потом', 'от', 'страх', 'чтобы', 'не', 'глядеть', 'на', 'платов', 'удариться', 'домой', 'да', 'где', 'попасть', 'спрятаться']
#
# ['nbsp', 'nbsp', 'свистовой', 'же', 'как', 'прискочить', 'сейчас', 'вскрикнуть', 'и', 'как', 'видеть', 'что', 'тот', 'не', 'отпирать', 'сейчас', 'без', 'церемония', 'рвануть', 'болт', 'у', 'ставень', 'но', 'болт', 'быть', 'такой', 'крепкий', 'что', 'нимало', 'не', 'податься', 'дёрнуть', 'дверь', 'а', 'дверь', 'изнутри', 'заложенный', 'на', 'дубовый', 'засов']
#
# ['тогда', 'свистовой', 'взять', 'с', 'улица', 'бревно', 'поддеть', 'он', 'на', 'пожарный', 'манер', 'под', 'кровельный', 'застреха', 'да', 'весь', 'крыша', 'с', 'маленький', 'домик', 'сразу', 'и', 'своротить']
#
# ['но', 'крыша', 'снять', 'да', 'и', 'сам', 'сейчас', 'повалиться', 'потому', 'что', 'у', 'мастер', 'в', 'он', 'тесный', 'хороминка', 'от', 'безотдышный', 'работа', 'в', 'воздух', 'такой', 'потный', 'спираль', 'сделаться', 'что', 'непривычный', 'человек', 'с', 'свежий', 'поветрие', 'и', 'один', 'раз', 'нельзя', 'быть', 'продохнуть']
#
# ['nbsp', 'nbsp', 'посол', 'закричать', 'nbsp', 'nbsp', 'что', 'же', 'вы', 'сволочь', 'делать', 'да', 'ещё', 'этака', 'спираль', 'ошибать', 'сметь']
#
# ['или', 'в', 'вы', 'после', 'этот', 'бог', 'нет']
#
# ['nbsp', 'nbsp', 'а', 'тот', 'отвечать', 'nbsp', 'nbsp', 'мы', 'сейчас', 'последний', 'гвоздик', 'заколачивать', 'и', 'как', 'забить', 'тогда', 'наш', 'работа', 'вынести']
#
# ['nbsp', 'nbsp', 'а', 'посол', 'говорить', 'nbsp', 'nbsp', 'он', 'мы', 'до', 'тот', 'час', 'живьём', 'съесть', 'и', 'на', 'помин', 'душа', 'не', 'оставить']
#
# ['nbsp', 'nbsp', 'но', 'мастер', 'отвечать', 'nbsp', 'nbsp', 'не', 'успеть', 'он', 'вы', 'поглотить', 'потому', 'вот', 'пока', 'вы', 'тут', 'говорить', 'у', 'мы', 'уже', 'и', 'этот', 'последний', 'гвоздь', 'заколоченный']
#
# ['бежать', 'и', 'сказать', 'что', 'сейчас', 'нести']
#
# ['nbsp', 'nbsp', 'свистовой', 'побежать', 'но', 'не', 'с', 'уверка', 'думать', 'что', 'мастер', 'он', 'обмануть', 'а', 'потому', 'бёжить', 'бёжить', 'да', 'оглянуться', 'но', 'мастер', 'за', 'он', 'идти', 'и', 'так', 'очень', 'скоро', 'поспешать', 'что', 'даже', 'не', 'вполне', 'как', 'следовать', 'для', 'явление', 'важный', 'лицо', 'одеться', 'а', 'на', 'ход', 'крючок', 'в', 'кафтан', 'застёгивать']
#
# ['у', 'два', 'у', 'он', 'в', 'рука', 'ничто', 'не', 'содержаться', 'а', 'у', 'три', 'у', 'левша', 'в', 'зелёный', 'чехол', 'царский', 'шкатулка', 'с', 'аглицкий', 'стальной', 'блоха']
#
# ['nbsp', 'nbsp', 'глава', 'десять', 'nbsp', 'nbsp', 'свистовой', 'подбежать', 'к', 'платов', 'и', 'говорить', 'nbsp', 'nbsp', 'вот', 'он', 'сам', 'здесь']
#
# ['nbsp', 'nbsp', 'плат', 'сейчас', 'к', 'мастер', 'nbsp', 'nbsp', 'готовый', 'ли']
#
# ['nbsp', 'nbsp', 'весь', 'отвечать', 'готовый']
#
# ['nbsp', 'nbsp', 'подавать', 'сюда']
#
# ['nbsp', 'nbsp', 'подать']
#
# ['nbsp', 'nbsp', 'а', 'экипаж', 'уже', 'запряжённый', 'и', 'ямщик', 'и', 'форейтор', 'на', 'место']
#
# ['казак', 'сейчас', 'же', 'ряд', 'с', 'ямщик', 'усесться', 'и', 'нагайка', 'над', 'он', 'поднять', 'и', 'так', 'замахнуть', 'и', 'держать']
#
# ['nbsp', 'nbsp', 'плат', 'сорвать', 'зелёный', 'чехол', 'открыть', 'шкатулка', 'вынуть', 'из', 'вата', 'золотой', 'табакерка', 'а', 'из', 'табакерка', 'бриллиантовый', 'орех', 'видеть', 'аглицкий', 'блоха', 'лежать', 'там', 'какой', 'быть', 'а', 'кроме', 'он', 'ничто', 'большой', 'нет']
#
# ['nbsp', 'nbsp', 'плат', 'говорить', 'nbsp', 'nbsp', 'это', 'что', 'же', 'такой']
#
# ['а', 'где', 'же', 'ваш', 'работа', 'котора', 'вы', 'хотеть', 'государь', 'утешить']
#
# ['nbsp', 'nbsp', 'оружейник', 'отвечать', 'nbsp', 'nbsp', 'тут', 'и', 'наш', 'работа']
#
# ['nbsp', 'nbsp', 'плат', 'спрашивать', 'nbsp', 'nbsp', 'в', 'что', 'же', 'он', 'себя', 'заключать']
#
# ['nbsp', 'nbsp', 'а', 'оружейник', 'отвечать', 'nbsp', 'nbsp', 'зачем', 'это', 'объяснять']
#
# ['весь', 'здесь', 'в', 'ваш', 'вид', 'и', 'предусматривать']
#
# ['nbsp', 'nbsp', 'плат', 'плечо', 'вздвигнуть', 'и', 'закричать', 'nbsp', 'nbsp', 'где', 'ключ', 'от', 'блоха']
#
# ['nbsp', 'nbsp', 'а', 'тут', 'же', 'отвечать', 'где', 'блоха', 'тут', 'и', 'ключ', 'в', 'один', 'орех']
#
# ['nbsp', 'nbsp', 'хотеть', 'плат', 'взять', 'ключ', 'но', 'палец', 'у', 'он', 'быть', 'куцапый', 'ловить', 'ловить', 'никак', 'не', 'мочь', 'ухватить', 'ни', 'блоха', 'ни', 'ключик', 'от', 'он', 'брюшной', 'завод', 'и', 'вдруг', 'рассердиться', 'и', 'начать', 'ругаться', 'слово', 'на', 'казацкий', 'манер']
#
# ['nbsp', 'nbsp', 'кричать', 'nbsp', 'nbsp', 'что', 'вы', 'подлец', 'ничто', 'не', 'сделать', 'да', 'ещё', 'пожалуй', 'весь', 'вещь', 'испортить']
#
# ['я', 'вы', 'голова', 'снять']
#
# ['nbsp', 'nbsp', 'а', 'туляк', 'он', 'в', 'ответ', 'nbsp', 'nbsp', 'напрасно', 'так', 'мы', 'обижать', 'мы', 'от', 'вы', 'как', 'от', 'государев', 'посол', 'весь', 'обида', 'должный', 'стерпеть', 'но', 'только', 'за', 'то', 'что', 'вы', 'в', 'мы', 'усумниться', 'и', 'подумать', 'будто', 'мы', 'даже', 'государев', 'имя', 'обмануть', 'сходственный', 'мы', 'вы', 'секрет', 'наш', 'работа', 'теперь', 'не', 'сказать', 'а', 'изволить', 'к', 'государь', 'отвезти', 'он', 'увидеть', 'каков', 'мы', 'у', 'он', 'человек', 'и', 'быть', 'ли', 'он', 'за', 'мы', 'постыждение']
#
# ['nbsp', 'nbsp', 'а', 'плат', 'крикнуть', 'nbsp', 'nbsp', 'ну', 'так', 'врать', 'же', 'вы', 'подлец', 'я', 'с', 'вы', 'так', 'не', 'расстануся', 'а', 'один', 'из', 'вы', 'со', 'я', 'в', 'петербург', 'поехать', 'и', 'я', 'он', 'там', 'допытаюся', 'какой', 'быть', 'ваш', 'хитрость']
#
# ['nbsp', 'nbsp', 'и', 'с', 'это', 'протянуть', 'рука', 'схватить', 'свой', 'куцапый', 'палец', 'за', 'шивороток', 'босой', 'левша', 'так', 'что', 'у', 'тот', 'весь', 'крючочек', 'от', 'казакин', 'отлететь', 'и', 'кинуть', 'он', 'к', 'себя', 'в', 'коляска', 'в', 'нога']
#
# ['nbsp', 'nbsp', 'сидеть', 'говорить', 'здесь', 'до', 'самый', 'петербург', 'вроде', 'пубель', 'ты', 'я', 'за', 'весь', 'ответить']
#
# ['а', 'вы', 'говорить', 'свистовой', 'теперь', 'гайда']
#
# ['не', 'зевать', 'чтобы', 'послезавтра', 'я', 'в', 'петербург', 'у', 'государь', 'быть']
#
# ['nbsp', 'nbsp', 'мастер', 'он', 'только', 'осмелиться', 'сказать', 'за', 'товарищ', 'что', 'как', 'же', 'мол', 'вы', 'он', 'от', 'мы', 'так', 'без', 'тугамент', 'увозить']
#
# ['он', 'нельзя', 'быть', 'назад', 'следовать']
#
# ['а', 'плат', 'он', 'вместо', 'ответ', 'показать', 'кулак', 'такой', 'страшный', 'бугровый', 'и', 'весь', 'изрубленный', 'срастись', 'и', 'погрозить', 'говорить', 'вот', 'вы', 'тугамент']
#
# ['а', 'казак', 'говорить', 'nbsp', 'nbsp', 'гайда', 'ребята']
#
# ['nbsp', 'nbsp', 'казак', 'ямщик', 'и', 'конь', 'весь', 'враз', 'заработать', 'и', 'умчать', 'левша', 'без', 'тугамент', 'а', 'через', 'день', 'как', 'приказать', 'плат', 'так', 'он', 'и', 'подкатить', 'к', 'государев', 'дворец', 'и', 'даже', 'расскакаться', 'как', 'следовать', 'мимо', 'колонна', 'проехать']
#
# ['nbsp', 'nbsp', 'плат', 'встать', 'подцепить', 'на', 'себя', 'орден', 'и', 'пойти', 'к', 'государь', 'а', 'косой', 'левша', 'велеть', 'свистовой', 'казак', 'при', 'подъезд', 'караулить']
#
# ['nbsp', 'nbsp', 'глава', 'одиннадцать', 'nbsp', 'nbsp', 'плат', 'бояться', 'к', 'государь', 'на', 'глаз', 'показаться', 'потому', 'что', 'николай', 'павло', 'быть', 'ужасно', 'какой', 'замечательный', 'и', 'памятный', 'ничто', 'не', 'забывать']
#
# ['плат', 'знать', 'что', 'он', 'непременно', 'он', 'о', 'блоха', 'спросить']
#
# ['и', 'вот', 'он', 'хоть', 'никакой', 'в', 'свет', 'неприятель', 'не', 'пугаться', 'а', 'тут', 'струсить', 'войти', 'в', 'дворец', 'со', 'шкатулочка', 'да', 'потихонечку', 'он', 'в', 'зал', 'за', 'печка', 'и', 'поставить']
#
# ['спрятать', 'шкатулка', 'плат', 'предстать', 'к', 'государь', 'в', 'кабинет', 'и', 'начать', 'скорый', 'докладывать', 'какой', 'у', 'казак', 'на', 'тихий', 'дон', 'междоусобный', 'разговор']
#
# ['думать', 'он', 'так', 'чтобы', 'это', 'государь', 'занять', 'и', 'тогда', 'если', 'государь', 'сам', 'вспомнить', 'и', 'заговорить', 'про', 'блоха', 'надо', 'подать', 'и', 'ответствовать', 'а', 'если', 'не', 'заговорить', 'то', 'промолчать', 'шкатулка', 'кабинетный', 'камердинер', 'велеть', 'спрятать', 'а', 'тульский', 'левша', 'в', 'крепостной', 'казамат', 'без', 'срок', 'посадить', 'чтобы', 'посидеть', 'там', 'до', 'время', 'если', 'понадобиться']
#
# ['nbsp', 'nbsp', 'но', 'государь', 'николай', 'павло', 'ни', 'о', 'что', 'не', 'забывать', 'и', 'чуть', 'плат', 'насчёт', 'междоусобный', 'разговор', 'кончить', 'он', 'он', 'сейчас', 'же', 'и', 'спрашивать', 'nbsp', 'nbsp', 'а', 'что', 'же', 'как', 'мой', 'тульский', 'мастер', 'против', 'аглицкий', 'нимфозорий', 'себя', 'оправдать']
#
# ['nbsp', 'nbsp', 'плат', 'отвечать', 'в', 'тот', 'род', 'как', 'он', 'дело', 'казаться']
#
# ['nbsp', 'nbsp', 'нимфозорий', 'говорить', 'ваш', 'величество', 'весь', 'в', 'тот', 'же', 'пространство', 'и', 'я', 'он', 'назад', 'привезти', 'а', 'тульский', 'мастер', 'ничто', 'удивительный', 'сделать', 'не', 'мочь']
#
# ['nbsp', 'nbsp', 'государь', 'ответить', 'nbsp', 'nbsp', 'ты', 'старик', 'мужественный', 'а', 'это', 'что', 'ты', 'я', 'докладывать', 'быть', 'не', 'мочь']
#
# ['nbsp', 'nbsp', 'плат', 'стать', 'он', 'уверять', 'и', 'рассказать', 'как', 'весь', 'дело', 'быть', 'и', 'как', 'досказать', 'до', 'тот', 'что', 'туляк', 'просить', 'он', 'блоха', 'государь', 'показать', 'николай', 'павло', 'он', 'по', 'плечо', 'хлопнуть', 'и', 'говорить', 'nbsp', 'nbsp', 'подавать', 'сюда']
#
# ['я', 'знать', 'что', 'мой', 'я', 'не', 'мочь', 'обманывать']
#
# ['тут', 'сверх', 'понятие', 'сделанный']
#
# ['nbsp', 'nbsp', 'глава', 'двенадцать', 'nbsp', 'nbsp', 'вынести', 'печка', 'шкатулка', 'снять', 'с', 'он', 'суконный', 'покров', 'открыть', 'золотой', 'табакерка', 'и', 'бриллиантовый', 'орех', 'а', 'в', 'он', 'блоха', 'лежать', 'какой', 'прежде', 'быть', 'и', 'как', 'лежать']
#
# ['nbsp', 'nbsp', 'государь', 'посмотреть', 'и', 'сказать', 'nbsp', 'nbsp', 'что', 'за', 'лихо']
#
# ['но', 'вера', 'свой', 'в', 'русский', 'мастер', 'не', 'убавить', 'а', 'велеть', 'позвать', 'свой', 'любимый', 'дочь', 'александр', 'николай', 'и', 'приказать', 'он', 'nbsp', 'nbsp', 'у', 'ты', 'на', 'рука', 'перст', 'тонкий', 'взять', 'маленький', 'ключик', 'и', 'завести', 'скорый', 'в', 'этот', 'нимфозорий', 'брюшной', 'машинка']
#
# ['nbsp', 'nbsp', 'принцесса', 'стать', 'крутить', 'ключик', 'и', 'блоха', 'сейчас', 'усик', 'зашевелить', 'но', 'нога', 'не', 'трогать']
#
# ...
#
# ['он', 'говорить', 'nbsp', 'nbsp', 'который', 'тут', 'быть', 'тот', 'должный', 'быть', 'глядеть']
#
# ['nbsp', 'nbsp', 'а', 'как', 'говорить', 'он', 'быть', 'в', 'перчатка', 'или', 'без', 'перчатка']
#
# ['nbsp', 'nbsp', 'ваш', 'генерал', 'говорить', 'парадное', 'он', 'всегда', 'в', 'перчатка', 'ходить', 'значит', 'и', 'здесь', 'так', 'быть']
#
# ['nbsp', 'nbsp', 'левша', 'ничто', 'не', 'сказать']
#
# ['но', 'вдруг', 'начать', 'беспокойно', 'скучать']
#
# ['затосковать', 'и', 'затосковать', 'и', 'говорить', 'англичанин', 'nbsp', 'nbsp', 'покорно', 'благрдарствовать', 'на', 'весь', 'угощение', 'и', 'я', 'весь', 'у', 'вы', 'очень', 'довольный', 'и', 'весь', 'что', 'я', 'нужный', 'быть', 'видеть', 'уже', 'видеть', 'а', 'теперь', 'я', 'скорый', 'домой', 'хотеть']
#
# ['nbsp', 'nbsp', 'никак', 'он', 'более', 'удержать', 'не', 'мочь']
#
# ['по', 'суша', 'он', 'пустить', 'нельзя', 'потому', 'что', 'он', 'на', 'весь', 'язык', 'не', 'уметь', 'а', 'по', 'вода', 'плыть', 'нехороший', 'быть', 'потому', 'что', 'время', 'быть', 'осенний', 'бурный', 'но', 'он', 'пристать', 'отпустить']
#
# ['nbsp', 'nbsp', 'мы', 'на', 'буреметр', 'говорить', 'смотреть', 'буря', 'быть', 'потонуть', 'мочь', 'это', 'ведь', 'не', 'то', 'что', 'у', 'вы', 'финский', 'залив', 'а', 'тут', 'настоящий', 'твердиземиий', 'море']
#
# ['nbsp', 'nbsp', 'это', 'весь', 'равно', 'отвечать', 'где', 'умереть', 'весь', 'единственный', 'воля', 'божий', 'а', 'я', 'желать', 'скорый', 'в', 'родной', 'место', 'потому', 'что', 'иначе', 'я', 'мочь', 'род', 'помешательство', 'достать']
#
# ['nbsp', 'nbsp', 'он', 'сило', 'не', 'удерживать', 'напитать', 'деньга', 'наградить', 'подарить', 'он', 'на', 'память', 'золотой', 'час', 'с', 'трепетир', 'а', 'для', 'морской', 'прохлада', 'на', 'поздний', 'осенний', 'путь', 'дать', 'байковый', 'пальто', 'с', 'ветряный', 'нахлобучка', 'на', 'голова']
#
# ['очень', 'тепло', 'одеть', 'и', 'отвезти', 'левша', 'на', 'корабль', 'который', 'в', 'россия', 'идти']
#
# ['тут', 'поместить', 'левша', 'в', 'хороший', 'вид', 'как', 'настоящий', 'барин', 'но', 'он', 'с', 'другой', 'господин', 'в', 'закрытие', 'сидеть', 'не', 'любить', 'и', 'совеститься', 'а', 'уйти', 'на', 'палуба', 'под', 'презент', 'сесть', 'и', 'спросить', 'где', 'наш', 'россия']
#
# ['nbsp', 'nbsp', 'англичанин', 'который', 'он', 'спрашивать', 'рука', 'он', 'в', 'тот', 'сторона', 'показать', 'или', 'голова', 'махнуть', 'а', 'он', 'туда', 'лицо', 'оборотиться', 'и', 'нетерпеливо', 'в', 'родной', 'сторона', 'смотреть']
#
# ['nbsp', 'nbsp', 'как', 'выйти', 'из', 'буфта', 'в', 'твердиземный', 'море', 'так', 'стремление', 'он', 'к', 'россия', 'такой', 'сделаться', 'что', 'никак', 'он', 'нельзя', 'быть', 'успокоить']
#
# ['водопление', 'стать', 'ужасный', 'а', 'левша', 'весь', 'вниз', 'в', 'каюта', 'нейти', 'под', 'презент', 'сидеть', 'нахлобучка', 'надвинуть', 'и', 'к', 'отечество', 'смотреть']
#
# ['nbsp', 'nbsp', 'много', 'раз', 'англичанин', 'приходить', 'он', 'в', 'тёплый', 'место', 'вниз', 'звать', 'но', 'он', 'чтобы', 'он', 'не', 'докучать', 'даже', 'отлыгаться', 'начать']
#
# ['nbsp', 'nbsp', 'нет', 'отвечать', 'я', 'тут', 'наружи', 'хороший', 'а', 'то', 'со', 'я', 'под', 'крыша', 'от', 'колтыхание', 'морской', 'свинка', 'сделаться']
#
# ['nbsp', 'nbsp', 'так', 'весь', 'время', 'и', 'не', 'сходить', 'до', 'особый', 'случай', 'и', 'через', 'это', 'очень', 'понравиться', 'один', 'полшкипер', 'который', 'на', 'горе', 'наш', 'левша', 'уметь', 'говорить']
#
# ['этот', 'полшкипер', 'не', 'мочь', 'надивиться', 'что', 'русский', 'сухопутный', 'человек', 'и', 'так', 'весь', 'непогода', 'выдерживать']
#
# ['nbsp', 'nbsp', 'молодец', 'говорить', 'русый']
#
# ['выпить']
#
# ['nbsp', 'nbsp', 'левша', 'выпить']
#
# ['nbsp', 'nbsp', 'а', 'полшкипер', 'говорить', 'nbsp', 'nbsp', 'ещё']
#
# ['nbsp', 'nbsp', 'левша', 'и', 'ещё', 'выпить', 'и', 'напиться']
#
# ['nbsp', 'nbsp', 'полшкипер', 'он', 'и', 'спрашивать', 'nbsp', 'nbsp', 'ты', 'какой', 'от', 'наш', 'государство', 'в', 'россия', 'секрет', 'везти']
#
# ['nbsp', 'nbsp', 'левша', 'отвечать', 'nbsp', 'nbsp', 'это', 'мой', 'дело']
#
# ['nbsp', 'nbsp', 'а', 'если', 'так', 'отвечать', 'полшкипер', 'так', 'давать', 'держать', 'с', 'ты', 'аглицкий', 'паря']
#
# ['nbsp', 'nbsp', 'левша', 'спрашивать', 'nbsp', 'nbsp', 'какой']
#
# ['nbsp', 'nbsp', 'такой', 'чтобы', 'ничто', 'в', 'одиночка', 'не', 'пить', 'а', 'всего', 'пить', 'заровно', 'что', 'один', 'то', 'непременно', 'и', 'другой', 'и', 'кто', 'кто', 'перепить', 'тот', 'и', 'горка']
#
# ['nbsp', 'nbsp', 'левша', 'думать', 'небо', 'тучиться', 'брюхо', 'пучиться', 'скука', 'большой', 'а', 'путина', 'длинный', 'и', 'родной', 'место', 'за', 'волна', 'не', 'видно', 'пари', 'держать', 'весёлый', 'быть']
#
# ['nbsp', 'nbsp', 'хорошо', 'говорить', 'идти']
#
# ['nbsp', 'nbsp', 'только', 'чтоб', 'честный']
#
# ['nbsp', 'nbsp', 'да', 'уж', 'это', 'говорить', 'не', 'беспокоиться']
#
# ['nbsp', 'nbsp', 'согласиться', 'и', 'по', 'рука', 'ударить']
#
# ['nbsp', 'nbsp', 'глава', 'семнадцать', 'nbsp', 'nbsp', 'начаться', 'у', 'он', 'пари', 'ещё', 'в', 'твердиземный', 'море', 'и', 'пить', 'он', 'до', 'рижский', 'динаминд', 'но', 'идти', 'всє', 'наравне', 'и', 'друг', 'друг', 'не', 'уступать', 'и', 'до', 'тот', 'аккуратно', 'равняться', 'что', 'когда', 'один', 'глянуть', 'в', 'море', 'увидать', 'как', 'из', 'вода', 'чёрт', 'лезть', 'так', 'сейчас', 'тот', 'же', 'самый', 'и', 'другой', 'объявиться']
#
# ['только', 'полшкипер', 'видеть', 'чёрт', 'рыжий', 'а', 'левша', 'говорить', 'будто', 'он', 'тёмный', 'как', 'мурина']
#
# ['nbsp', 'nbsp', 'левша', 'говорить', 'nbsp', 'nbsp', 'перекреститься', 'и', 'отворотиться', 'это', 'чёрт', 'из', 'пучина']
#
# ['nbsp', 'nbsp', 'а', 'англичанин', 'спорить', 'что', 'это', 'морской', 'водоглаз']
#
# ['nbsp', 'nbsp', 'хотеть', 'говорить', 'я', 'ты', 'в', 'море', 'швырнуть']
#
# ['ты', 'не', 'бояться', 'он', 'я', 'ты', 'сейчас', 'назад', 'подать']
#
# ['nbsp', 'nbsp', 'а', 'левша', 'отвечать', 'nbsp', 'nbsp', 'если', 'так', 'то', 'швырять']
#
# ['nbsp', 'nbsp', 'полшкипер', 'он', 'взять', 'на', 'закорки', 'и', 'понести', 'к', 'борт']
#
# ['nbsp', 'nbsp', 'матрос', 'это', 'увидать', 'остановить', 'он', 'и', 'доложить', 'капитан', 'а', 'то', 'велеть', 'он', 'оба', 'вниз', 'запереть', 'и', 'дать', 'он', 'ром', 'и', 'вино', 'и', 'холодный', 'пища', 'чтобы', 'мочь', 'и', 'пить', 'и', 'есть', 'и', 'свой', 'пари', 'выдержать', 'а', 'горячий', 'студинг', 'с', 'огонь', 'он', 'не', 'подавать', 'потому', 'что', 'у', 'он', 'в', 'нутро', 'мочь', 'спирт', 'загореться']
#
# ['nbsp', 'nbsp', 'так', 'он', 'и', 'привезти', 'взаперти', 'до', 'петербург', 'и', 'пари', 'из', 'он', 'ни', 'один', 'друг', 'у', 'друг', 'не', 'выиграть', 'а', 'тут', 'раскласть', 'он', 'на', 'разный', 'повозка', 'и', 'повезти', 'англичанин', 'в', 'посланнический', 'дом', 'на', 'аглицкий', 'набережная', 'а', 'левша', 'в', 'квартал']
#
# ['nbsp', 'nbsp', 'отсюда', 'судьба', 'он', 'начать', 'сильно', 'разниться']
#
# ['nbsp', 'nbsp', 'глава', 'восемнадцать', 'nbsp', 'nbsp', 'англичанин', 'как', 'привезти', 'в', 'посольский', 'дом', 'сейчас', 'сразу', 'позвать', 'к', 'он', 'лекарь', 'и', 'аптекарь']
#
# ['лекарь', 'велеть', 'он', 'при', 'себя', 'в', 'тёплый', 'ванна', 'всадить', 'а', 'аптекарь', 'сейчас', 'же', 'скатать', 'гуттаперчевый', 'пилюля', 'и', 'сам', 'в', 'рот', 'он', 'всунуть', 'а', 'потом', 'оба', 'вместе', 'взяться', 'и', 'положить', 'на', 'перина', 'и', 'сверху', 'шуба', 'покрыть', 'и', 'оставить', 'потеть', 'а', 'чтобы', 'он', 'никто', 'не', 'мешать', 'по', 'весь', 'посольство', 'приказ', 'данный', 'чтобы', 'никто', 'чихать', 'не', 'сметь']
#
# ['дождаться', 'лекарь', 'с', 'аптекарь', 'пока', 'полшкипер', 'заснуть', 'и', 'тогда', 'другой', 'гуттаперчевый', 'пилюля', 'он', 'приготовить', 'возле', 'он', 'изголовье', 'на', 'столик', 'положить', 'и', 'уйти']
#
# ['nbsp', 'nbsp', 'а', 'левша', 'свалить', 'в', 'квартал', 'на', 'пол', 'и', 'спрашивать', 'nbsp', 'nbsp', 'кто', 'такой', 'и', 'откудова', 'и', 'быть', 'ли', 'паспорт', 'или', 'какой', 'другой', 'тугамент']
#
# ['nbsp', 'nbsp', 'а', 'он', 'от', 'болезнь', 'от', 'питие', 'и', 'от', 'долгий', 'колтыхание', 'так', 'ослабеть', 'что', 'ни', 'слово', 'не', 'отвечать', 'а', 'только', 'стонать']
#
# ['nbsp', 'nbsp', 'тогда', 'он', 'сейчас', 'обыскать', 'пёстрый', 'платье', 'с', 'он', 'снять', 'и', 'час', 'с', 'трепетир', 'и', 'деньга', 'обрать', 'а', 'самый', 'пристав', 'велеть', 'на', 'встречный', 'извозчик', 'бесплатно', 'в', 'больница', 'отправить']
#
# ['nbsp', 'nbsp', 'повести', 'городов', 'левша', 'на', 'санки', 'сажать', 'да', 'долго', 'ни', 'один', 'встречник', 'поймать', 'не', 'мочь', 'потому', 'извозчик', 'от', 'полицейский', 'бегать']
#
# ['а', 'левша', 'весь', 'время', 'на', 'холодный', 'парат', 'лежать', 'потом', 'поймать', 'городовой', 'извозчик', 'только', 'без', 'тёплый', 'лиса', 'потому', 'что', 'он', 'лиса', 'в', 'сани', 'в', 'такой', 'раз', 'под', 'себя', 'прятать', 'чтобы', 'у', 'полицейский', 'скорый', 'нога', 'стынуть']
#
# ['везти', 'левша', 'так', 'непокрытый', 'да', 'как', 'с', 'один', 'извозчик', 'на', 'другой', 'стать', 'пересаживать', 'всє', 'ронять', 'а', 'поднимать', 'стать', 'уха', 'рвать', 'чтобы', 'в', 'память', 'прийти']
#
# ['nbsp', 'nbsp', 'привезти', 'в', 'один', 'больница', 'не', 'принимать', 'без', 'тугамент', 'привезти', 'в', 'другой', 'и', 'там', 'не', 'принимать', 'и', 'так', 'в', 'треть', 'и', 'в', 'четвертовать', 'до', 'самый', 'утро', 'он', 'по', 'весь', 'отдалённый', 'кривопутка', 'таскать', 'и', 'весь', 'пересаживать', 'так', 'что', 'он', 'весь', 'избиться']
#
# ['тогда', 'один', 'подлекарь', 'сказать', 'городовой', 'везти', 'он', 'в', 'простонародный', 'обухвинский', 'больница', 'где', 'неведомый', 'сословие', 'весь', 'умирать', 'принимать']
#
# ['nbsp', 'nbsp', 'тут', 'велеть', 'расписка', 'дать', 'а', 'левша', 'до', 'разборка', 'на', 'пол', 'в', 'коридор', 'посадить']
#
# ['nbsp', 'nbsp', 'а', 'аглицкий', 'полшкипер', 'в', 'этот', 'самый', 'время', 'на', 'другой', 'день', 'встать', 'другой', 'гуттаперчевый', 'пилюля', 'в', 'нутро', 'проглотить', 'на', 'лёгкий', 'завтрак', 'курица', 'с', 'рысь', 'съесть', 'ерфикс', 'запить', 'и', 'говорить', 'nbsp', 'nbsp', 'где', 'мой', 'русский', 'камрад']
#
# ['я', 'он', 'искать', 'пойти']
#
# ['nbsp', 'nbsp', 'одеться', 'и', 'побежать']
#
# ['nbsp', 'nbsp', 'глава', 'девятнадцать', 'nbsp', 'nbsp', 'удивительный', 'манер', 'полшкипер', 'очень', 'скоро', 'левша', 'найти', 'только', 'он', 'ещё', 'на', 'кровать', 'не', 'уложить', 'а', 'он', 'в', 'коридор', 'на', 'пол', 'лежать', 'и', 'жаловаться', 'англичанин']
#
# ['nbsp', 'nbsp', 'я', 'бы', 'говорить', 'два', 'слово', 'государь', 'непременно', 'надо', 'сказать']
#
# ['nbsp', 'nbsp', 'англичанин', 'побежать', 'к', 'граф', 'клейнмихель', 'и', 'зашуметь', 'nbsp', 'nbsp', 'разве', 'так', 'можно']
#
# ['у', 'он', 'говорить', 'хоть', 'и', 'шуба', 'овечкин', 'так', 'душа', 'человечкин']
#
# ['nbsp', 'nbsp', 'англичанин', 'сейчас', 'оттуда', 'за', 'этот', 'рассуждение', 'вон', 'чтобы', 'не', 'сметь', 'поминать', 'душа', 'человечкин']
#
# ['а', 'потом', 'он', 'сказать', 'сходить', 'бы', 'ты', 'хороший', 'к', 'казак', 'платов', 'он', 'простой', 'чувство', 'иметь']
#
# ['nbsp', 'nbsp', 'англичанин', 'достигнуть', 'платов', 'который', 'теперь', 'опять', 'на', 'укушетка', 'лежать']
#
# ['плат', 'он', 'выслушать', 'и', 'про', 'левша', 'вспомнить']
#
# ['nbsp', 'nbsp', 'как', 'же', 'братец', 'говорить', 'очень', 'коротко', 'с', 'он', 'знакомый', 'даже', 'за', 'волос', 'он', 'драть', 'только', 'не', 'знать', 'как', 'он', 'в', 'такой', 'несчастный', 'раз', 'помочь', 'потому', 'что', 'я', 'уже', 'совсем', 'отслужиться', 'и', 'полный', 'пуплекция', 'получить', 'теперь', 'я', 'большой', 'не', 'уважать', 'а', 'ты', 'бежать', 'скорый', 'к', 'комендант', 'скобелев', 'он', 'в', 'сила', 'и', 'тоже', 'в', 'этот', 'часть', 'опытный', 'он', 'сделать']
#
# ['nbsp', 'nbsp', 'полшкипер', 'пойти', 'и', 'к', 'скобелев', 'и', 'весь', 'рассказать', 'какой', 'у', 'левша', 'болезнь', 'и', 'отчего', 'сделаться']
#
# ['скобелев', 'говорить', 'nbsp', 'nbsp', 'я', 'этот', 'болезнь', 'понимать', 'только', 'немец', 'он', 'лечить', 'не', 'мочь', 'а', 'тут', 'надо', 'доктор', 'из', 'духовный', 'звание', 'потому', 'что', 'тот', 'в', 'этот', 'пример', 'вырасти', 'и', 'помогать', 'мочь', 'я', 'сейчас', 'послать', 'туда', 'русский', 'доктор']
#
# ['nbsp', 'nbsp', 'но', 'только', 'когда', 'приехать', 'левша', 'уже', 'кончаться', 'потому', 'что', 'у', 'он', 'затылок', 'о', 'паратый', 'расколоться', 'и', 'он', 'один', 'только', 'мочь', 'внятно', 'выговорить', 'nbsp', 'nbsp', 'сказать', 'государь', 'что', 'у', 'англичанин', 'ружьё', 'кирпич', 'не', 'чистить', 'пусть', 'чтобы', 'и', 'у', 'мы', 'не', 'чистить', 'а', 'то', 'хранить', 'бог', 'война', 'он', 'стрелять', 'не', 'годиться']
#
# ['nbsp', 'nbsp', 'и', 'с', 'этой', 'верность', 'левша', 'перекреститься', 'и', 'помереть']
#
# ['сейчас', 'же', 'поехать', 'об', 'это', 'граф', 'чернышев', 'доложить', 'чтобы', 'до', 'государь', 'довести', 'а', 'граф', 'чернышев', 'на', 'он', 'закричать', 'nbsp', 'nbsp', 'знать', 'говорить', 'свой', 'рвотный', 'да', 'слабительный', 'а', 'не', 'в', 'свой', 'дело', 'не', 'мешаться', 'в', 'россия', 'на', 'это', 'генерал', 'быть']
#
# ['nbsp', 'nbsp', 'государь', 'так', 'и', 'не', 'сказать', 'и', 'чистка', 'весь', 'продолжаться', 'до', 'самый', 'крымский', 'кампания']
#
# ['в', 'тогдашний', 'время', 'как', 'стать', 'ружьё', 'заряжать', 'а', 'пуля', 'в', 'он', 'и', 'болтаться', 'потому', 'что', 'ствол', 'кирпич', 'расчищенный']
#
# ['nbsp', 'nbsp', 'тут', 'чернышев', 'о', 'левша', 'и', 'напомнить', 'а', 'граф', 'чернышев', 'и', 'говорить', 'nbsp', 'nbsp', 'пойти', 'к', 'чёрт', 'плезирный', 'трубка', 'не', 'в', 'свой', 'дело', 'не', 'мешаться', 'а', 'не', 'тот', 'я', 'отпереться', 'что', 'никогда', 'от', 'ты', 'об', 'это', 'не', 'слыхать', 'ты', 'же', 'и', 'достаться']
#
# ['nbsp', 'nbsp', 'подумать', 'и', 'вправду', 'отпереться', 'так', 'и', 'молчать']
#
# ['nbsp', 'nbsp', 'а', 'доведь', 'он', 'левшин', 'слово', 'в', 'свой', 'время', 'до', 'государь', 'в', 'крым', 'на', 'война', 'с', 'неприятель', 'совсем', 'бы', 'другой', 'оборот', 'быть']
#
# ['nbsp', 'nbsp', 'глава', 'двадцать', 'nbsp', 'nbsp', 'теперь', 'весь', 'это', 'уже', 'дело', 'минувший', 'день', 'и', 'предание', 'старина', 'хотя', 'и', 'не', 'глубокий', 'но', 'предание', 'этот', 'нет', 'нужда', 'торопиться', 'забывать', 'несмотря', 'на', 'баснословный', 'склад', 'легенда', 'и', 'эпический', 'характер', 'он', 'главный', 'герой']
#
# ['собственный', 'имя', 'левша', 'подобно', 'имя', 'многий', 'великий', 'гений', 'навсегда', 'утраченный', 'для', 'потомство', 'но', 'как', 'олицетворённый', 'народный', 'фантазия', 'миф', 'он', 'интересный', 'а', 'он', 'похождение', 'мочь', 'служить', 'воспоминание', 'эпоха', 'общий', 'дух', 'который', 'схваченный', 'метко', 'и', 'верно']
#
# ['nbsp', 'nbsp', 'такой', 'мастер', 'как', 'баснословный', 'левша', 'теперь', 'разумеется', 'уже', 'нет', 'в', 'тула', 'машина', 'сравнять', 'неравенство', 'талант', 'и', 'дарование', 'и', 'гений', 'не', 'рваться', 'в', 'борьба', 'против', 'прилежание', 'и', 'аккуратность']
#
# ['благоприятствовать', 'возвышение', 'заработок', 'машина', 'не', 'благоприятствовать', 'артистический', 'удаль', 'который', 'иногда', 'превосходить', 'мера', 'вдохновлять', 'народный', 'фантазия', 'к', 'сочинение', 'подобный', 'нынешний', 'баснословный', 'легенда']
#
# ['nbsp', 'nbsp', 'работник', 'конечно', 'уметь', 'ценить', 'выгода', 'доставляемый', 'он', 'практический', 'приспособление', 'механический', 'наука', 'но', 'о', 'прежний', 'старина', 'он', 'вспоминать', 'с', 'гордость', 'и', 'любовь']
#
# ['это', 'он', 'эпос', 'и', 'притом', 'с', 'очень', 'человечкин', 'душа']
#
# ['nbsp', 'nbsp', 'nbsp', 'nbsp', 'nbsp', 'nbsp', 'nbsp', 'nbsp', 'комментарий', 'последний', 'от']
#
# ['лесок', 'николай', 'семён', 'год', 'обновлённый']
#
# []
#
# ['статистика']
#
# ['рассказ', 'сказка', 'оценка', 'nbsp', 'ваш', 'оценка', 'шедевр', 'замечательный', 'очень', 'хорошо', 'хорошо', 'нормальный', 'не', 'читать', 'терпимо', 'посредственно', 'плохо', 'очень', 'плохо', 'не', 'читать', 'нижний', 'горизонтальный', 'блок', 'для', 'azlib', 'script', 'http', 'связаться', 'с', 'программист', 'сайт']
#
# ['var', 'function', 'var', 'script', 'var', 'script', 'e', 't']

# %% [markdown]
# Проверьте себя. Должны получиться следующие значения:
#
# *   Предложений: 576
# *   Токенов: 8637

# %%
'.'.isalpha()
# Out:
# False

# %%
len(predictions)
# Out:
# 468

# %%
non_uniq_tokens = [word for sentence in predictions for word in sentence]
len(non_uniq_tokens)
# Out:
# 9951

# %% [markdown]
# Для продолжения работы над заданием числа должны совпасть!

# %% [markdown]
# ## Задание 2
#
# Используя `non_uniq_tokens`, стоп-слова для русского языка из библиотеки nltk (`nltk.corpus.stopwords`) и `nltk.FreqDist`, вычислите, **какую долю среди 100 самых частотных** токенов в произведении занимают токены, **не относящиеся** к стоп словам.
#
# **Не бойтесь использовать документацию NLTK и тьюториалы.**

# %%
import nltk
from nltk import FreqDist
from nltk.corpus import stopwords
nltk.download("stopwords")
STOPWORDS = set(stopwords.words("russian"))
stopwords.words("russian")[:5]#Пример стоп слов
arrStops=stopwords.words("russian")
print(arrStops)
# Out:
# ['и', 'в', 'во', 'не', 'что', 'он', 'на', 'я', 'с', 'со', 'как', 'а', 'то', 'все', 'она', 'так', 'его', 'но', 'да', 'ты', 'к', 'у', 'же', 'вы', 'за', 'бы', 'по', 'только', 'ее', 'мне', 'было', 'вот', 'от', 'меня', 'еще', 'нет', 'о', 'из', 'ему', 'теперь', 'когда', 'даже', 'ну', 'вдруг', 'ли', 'если', 'уже', 'или', 'ни', 'быть', 'был', 'него', 'до', 'вас', 'нибудь', 'опять', 'уж', 'вам', 'ведь', 'там', 'потом', 'себя', 'ничего', 'ей', 'может', 'они', 'тут', 'где', 'есть', 'надо', 'ней', 'для', 'мы', 'тебя', 'их', 'чем', 'была', 'сам', 'чтоб', 'без', 'будто', 'чего', 'раз', 'тоже', 'себе', 'под', 'будет', 'ж', 'тогда', 'кто', 'этот', 'того', 'потому', 'этого', 'какой', 'совсем', 'ним', 'здесь', 'этом', 'один', 'почти', 'мой', 'тем', 'чтобы', 'нее', 'сейчас', 'были', 'куда', 'зачем', 'всех', 'никогда', 'можно', 'при', 'наконец', 'два', 'об', 'другой', 'хоть', 'после', 'над', 'больше', 'тот', 'через', 'эти', 'нас', 'про', 'всего', 'них', 'какая', 'много', 'разве', 'три', 'эту', 'моя', 'впрочем', 'хорошо', 'свою', 'этой', 'перед', 'иногда', 'лучше', 'чуть', 'том', 'нельзя', 'такой', 'им', 'более', 'всегда', 'конечно', 'всю', 'между']
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Xiaomi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
frequency = {}
for sent in predictions:
    for word in sent:
        count = frequency.get(word,0)
        frequency[word] = count + 1
import operator
col=0
for key, value in frequency.items():
    stop=0
    if (key in arrStops):
        stop=1
    #print(key, value,stop)
    if col==99: break
        
ind=1
val_stop=0
val_norm=0
in_stop=0
for w in sorted(frequency, key=frequency.get, reverse=True):
    mark=0
    if (w in arrStops):
        val_stop+=frequency[w]
        mark=1
        in_stop+=1
    else:
        val_norm+=frequency[w]
    #print (ind,w, frequency[w],mark)
    ind+=1
    if (ind==101): break
print('ans',(100-in_stop)/100)
print(in_stop)
#print('частота стопслов',val_stop,'частота не стоп слов',val_norm)
#print('отношение стоп слов к топ-100',round((val_stop*100)/(val_norm+val_stop),1))
# Out:
# ans 0.46
# 54

# %% [markdown]
# Проверьте себя: должно получиться 0.49

# %% [markdown]
# ## Задание 3
# Вычислите, сколько токенов встречается в тексте **строго больше** 50 раз.

# %% [markdown]
# Проверьте себя: должно получиться значение 22
